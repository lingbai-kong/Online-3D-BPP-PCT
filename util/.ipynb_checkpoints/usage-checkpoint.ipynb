# %%
import gym
import copy
import numpy as np
import torch
import sys 
sys.path.append("..")
sys.path.append("../MCTS")
from monteCarlo import MCTree
import tools
from tools import get_args, registration_envs
registration_envs()
# Out:
# ../pretrained_models/PCT_setting1.pt
# Loading pre-train upper model ../pretrained_models/PCT_setting1.pt
# Pre-train model loaded! ../pretrained_models/PCT_setting1.pt

# %%
class usage():
    def __init__(self,K=3):
        self.K=K
        self.box_size_list=[]
        self.simulation_times, self.search_depth, self.rollout_length = (50, None, -1)
        self.mctree=None
        self.new=True
        self.action=None
        
        args = get_args()
        self.env = gym.make(args.id,
                           setting = args.setting,
                           item_set = args.item_size_set,
                           container_size=args.container_size,
                           data_name=args.dataset_path,
                           load_test_data=args.load_dataset,
                           internal_node_holder = args.internal_node_holder,
                           leaf_node_holder = args.leaf_node_holder,
                           LNES = args.lnes,
                           shuffle=args.shuffle,
                           sample_from_distribution=args.sample_from_distribution,
                           sample_left_bound=args.sample_left_bound,
                           sample_right_bound=args.sample_right_bound
                           )
        if args.no_cuda:
            self.device = torch.device('cpu')
        else:
            self.device = torch.device('cuda', args.device)
            torch.cuda.set_device(self.device)
        self.reset()
    def reset(self):
        self.box_size_list=[]
        self.mctree=None
        self.new=True
        self.action=None
        self.obs=self.env.reset()
        self.env.box_creator.preview(1000)
        
    def go(self,box):
        if len(self.box_size_list)<self.K-1: #1~K-1
            self.env.box_creator.box_list[len(self.box_size_list)]=box
            self.box_size_list.append(box)
            return False,None,None
        else: # K
            if self.new:
                self.env.box_creator.box_list[self.K-1]=box
                self.box_size_list.append(box)
                self.obs=self.env.cur_observation()
                self.mctree = MCTree(copy.deepcopy(self.env), copy.deepcopy(self.obs), self.box_size_list, search_depth=self.search_depth, rollout_length=self.rollout_length)
                self.new=False
            else:
                self.env.box_creator.box_list[self.K-1]=box
                self.box_size_list.pop(0)
                self.box_size_list.append(box)
                self.obs=self.env.cur_observation()
                self.mctree = MCTree(copy.deepcopy(self.env), copy.deepcopy(self.obs), self.box_size_list, search_depth=self.search_depth, rollout_length=self.rollout_length)
#                 self.env.box_creator.box_list[self.K-1]=box
#                 self.obs=self.env.cur_observation()
#                 self.mctree.succeed(self.action, box, self.obs)
            
            pl = self.mctree.get_policy(self.simulation_times, zeta=1e-5)
            act_node = self.mctree.sample_action(pl)
            
            # update env
            assert self.env.next_box == self.box_size_list[0]
            obs, r, done, dt = self.env.step(act_node, 'testMCTS')
            self.action = dt['box_action']
            print(self.action)

            if done:
                self.reset()
                return True,self.action,[dt['ratio'], dt['counter'], dt['reward']]
            else:
                return False,self.action,None

# %% [markdown]
# # Generate boxes sequence

# %%
import pickle
boxes = []
for _ in range(10000):
    box=(np.random.randint(1,6),np.random.randint(1,6),np.random.randint(1,6))
    boxes.append(box)
with open('box_seq.plk','wb') as f:
    pickle.dump(boxes,f)
    f.close()

# %%
import pickle
boxes = []
with open('box_seq.plk','rb') as f:
    boxes = pickle.load(f)
    f.close()

# %% [markdown]
# # experiment

# %%
import time
import csv
agent = usage(9)
results = []
actions = []
for no, box in enumerate(boxes):
    is_done,action,result=agent.go(box)
    if action != None:
        actions.append(action)
    if is_done:
        t = time.strftime('%Y.%m.%d-%H-%M-%S', time.localtime(time.time()))
        with open(f'actions/{t}.csv','w') as f:
            csv_writer = csv.writer(f)
            for act in actions:
                csv_writer.writerow(act)
            f.close()
        actions=[]
        
        print(result)
        results.append(result)
        if len(results)>=30:
            break
# Out:
# /root/anaconda3/envs/intelcup/lib/python3.7/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# cost time 3.778722
# terminated node: 0
# reached depth: 8
# (1, 4, 2, 0, 6, 0)
# cost time 4.532779999999999
# terminated node: 0
# reached depth: 8
# (1, 5, 2, 0, 5, 2)
# cost time 5.190770999999998
# terminated node: 0
# reached depth: 8
# (2, 5, 5, 1, 5, 0)
# cost time 5.054539999999999
# terminated node: 0
# reached depth: 8
# (2, 4, 2, 8, 6, 0)
# cost time 4.773263
# terminated node: 0
# reached depth: 7
# (2, 4, 4, 3, 6, 0)
# cost time 4.081195000000001
# terminated node: 0
# reached depth: 8
# (2, 4, 1, 6, 6, 0)
# cost time 4.9446980000000025
# terminated node: 0
# reached depth: 6
# (4, 5, 5, 6, 5, 2)
# cost time 4.470925000000001
# terminated node: 0
# reached depth: 8
# (2, 3, 2, 8, 7, 7)
# cost time 4.115076999999999
# terminated node: 0
# reached depth: 7
# (1, 4, 2, 5, 6, 0)
# cost time 5.214594000000005
# terminated node: 0
# reached depth: 6
# (4, 5, 4, 6, 0, 0)
# cost time 4.292164999999997
# terminated node: 0
# reached depth: 7
# (3, 4, 3, 3, 6, 4)
# cost time 4.1732390000000095
# terminated node: 0
# reached depth: 8
# (3, 5, 4, 0, 5, 5)
# cost time 4.930996999999991
# terminated node: 0
# reached depth: 8
# (3, 3, 3, 5, 7, 7)
# cost time 5.087755000000001
# terminated node: 0
# reached depth: 8
# (5, 5, 3, 0, 0, 0)
# cost time 4.335478000000009
# terminated node: 0
# reached depth: 8
# (1, 1, 5, 5, 5, 0)
# cost time 4.484507000000008
# terminated node: 0
# reached depth: 8
# (1, 4, 4, 5, 0, 0)
# cost time 3.8616779999999977
# terminated node: 0
# reached depth: 8
# (2, 5, 5, 8, 0, 4)
# cost time 4.648148000000006
# terminated node: 0
# reached depth: 8
# (2, 1, 5, 3, 5, 0)
# cost time 4.673401999999996
# terminated node: 0
# reached depth: 8
# (2, 4, 2, 3, 6, 7)
# cost time 4.148454000000001
# terminated node: 0
# reached depth: 8
# (4, 5, 2, 0, 0, 3)
# cost time 3.156871999999993
# terminated node: 0
# reached depth: 8
# (4, 4, 1, 0, 6, 9)
# cost time 3.4183790000000016
# terminated node: 0
# reached depth: 8
# (1, 4, 4, 7, 1, 4)
# cost time 3.1358299999999986
# terminated node: 0
# reached depth: 8
# (5, 1, 3, 5, 6, 7)
# cost time 2.612566000000001
# terminated node: 15
# reached depth: 8
# (1, 5, 4, 6, 0, 4)
# cost time 1.8503829999999937
# terminated node: 19
# reached depth: 6
# (4, 1, 2, 6, 5, 7)
# cost time 2.233310000000003
# terminated node: 19
# reached depth: 5
# (2, 3, 1, 8, 7, 9)
# cost time 1.8197799999999944
# terminated node: 19
# reached depth: 4
# (3, 3, 2, 5, 2, 8)
# cost time 1.340999999999994
# terminated node: 28
# reached depth: 3
# (2, 3, 5, 3, 3, 5)
# cost time 0.8427639999999883
# terminated node: 47
# reached depth: 2
# (1, 3, 3, 4, 0, 3)
# cost time 0.6426429999999925
# terminated node: 48
# reached depth: 1
# (3, 3, 3, 2, 0, 6)
# cost time 0.562098000000006
# terminated node: 49
# reached depth: 0
# (5, 3, 5, 0, 0, 9)
# [0.824, 30, 8.24]
# cost time 4.7122249999999894
# terminated node: 0
# reached depth: 8
# (3, 4, 3, 0, 6, 0)
# cost time 4.654691000000014
# terminated node: 0
# reached depth: 8
# (2, 5, 4, 0, 5, 3)
# cost time 4.2136540000000196
# terminated node: 0
# reached depth: 8
# (1, 4, 3, 3, 6, 0)
# cost time 3.3073459999999955
# terminated node: 0
# reached depth: 8
# (3, 4, 3, 7, 6, 0)
# cost time 3.576254000000006
# terminated node: 0
# reached depth: 8
# (3, 1, 4, 4, 9, 0)
# cost time 3.2891810000000135
# terminated node: 0
# reached depth: 8
# (1, 3, 2, 6, 6, 0)
# cost time 3.871204999999975
# terminated node: 0
# reached depth: 8
# (1, 1, 1, 5, 8, 0)
# cost time 4.341061999999994
# terminated node: 0
# reached depth: 8
# (2, 3, 2, 8, 7, 3)
# cost time 4.3733
# terminated node: 0
# reached depth: 8
# (2, 2, 4, 4, 6, 0)
# cost time 4.488827000000015
# terminated node: 0
# reached depth: 8
# (4, 1, 1, 6, 5, 0)
# cost time 4.4088529999999935
# terminated node: 0
# reached depth: 8
# (1, 4, 1, 7, 6, 3)
# cost time 4.435721999999998
# terminated node: 0
# reached depth: 8
# (2, 4, 4, 8, 6, 5)
# cost time 4.456770000000006
# terminated node: 0
# reached depth: 8
# (1, 4, 5, 7, 6, 4)
# cost time 4.417059999999992
# terminated node: 0
# reached depth: 8
# (2, 5, 4, 5, 5, 4)
# cost time 4.477494000000007
# terminated node: 0
# reached depth: 8
# (2, 5, 2, 2, 5, 3)
# cost time 4.1699199999999905
# terminated node: 0
# reached depth: 8
# (2, 5, 2, 3, 5, 5)
# cost time 5.05882299999999
# terminated node: 0
# reached depth: 8
# (2, 2, 2, 8, 4, 1)
# cost time 4.676166000000023
# terminated node: 0
# reached depth: 8
# (1, 4, 3, 9, 0, 0)
# cost time 3.9537369999999896
# terminated node: 0
# reached depth: 8
# (3, 5, 3, 0, 5, 7)
# cost time 4.7473520000000065
# terminated node: 0
# reached depth: 8
# (1, 4, 4, 8, 0, 0)
# cost time 4.555965000000015
# terminated node: 0
# reached depth: 8
# (1, 5, 1, 9, 5, 9)
# cost time 4.689576999999986
# terminated node: 0
# reached depth: 8
# (3, 5, 4, 5, 0, 0)
# cost time 4.474119999999999
# terminated node: 0
# reached depth: 8
# (1, 5, 1, 8, 5, 9)
# cost time 4.286414000000008
# terminated node: 0
# reached depth: 8
# (1, 4, 4, 9, 1, 3)
# cost time 4.19072700000001
# terminated node: 0
# reached depth: 6
# (4, 5, 2, 0, 0, 0)
# cost time 3.9370619999999974
# terminated node: 0
# reached depth: 8
# (1, 3, 2, 4, 7, 7)
# cost time 3.573332000000022
# terminated node: 0
# reached depth: 8
# (5, 5, 4, 0, 0, 2)
# cost time 2.436784999999986
# terminated node: 15
# reached depth: 7
# (1, 5, 2, 6, 5, 8)
# cost time 2.4771639999999877
# terminated node: 16
# reached depth: 6
# (3, 4, 4, 6, 1, 4)
# cost time 1.513540000000006
# terminated node: 36
# reached depth: 5
# (2, 4, 2, 8, 1, 8)
# cost time 1.025652999999977
# terminated node: 41
# reached depth: 4
# (2, 4, 2, 6, 1, 8)
# cost time 0.975309999999979
# terminated node: 44
# reached depth: 3
# (2, 4, 3, 3, 3, 7)
# cost time 0.806888999999984
# terminated node: 46
# reached depth: 2
# (5, 1, 5, 5, 0, 4)
# cost time 0.6809760000000153
# terminated node: 48
# reached depth: 1
# (3, 5, 4, 0, 0, 6)
# cost time 0.6043019999999899
# terminated node: 49
# reached depth: 0
# (3, 2, 5, 0, 0, 10)
# [0.823, 34, 8.23]
# cost time 4.308237999999989
# terminated node: 0
# reached depth: 8
# (3, 5, 4, 0, 5, 0)
# cost time 3.7398399999999583
# terminated node: 0
# reached depth: 8
# (1, 5, 5, 9, 5, 0)
# cost time 4.445250999999985
# terminated node: 0
# reached depth: 8
# (1, 4, 4, 8, 6, 0)
# cost time 4.6128420000000006
# terminated node: 0
# reached depth: 8
# (1, 4, 3, 7, 6, 0)
# cost time 4.237935999999991
# terminated node: 0
# reached depth: 8
# (1, 5, 4, 6, 5, 0)
# cost time 4.50376
# terminated node: 0
# reached depth: 8
# (1, 4, 3, 5, 6, 0)
# cost time 4.709820999999977
# terminated node: 0
# reached depth: 8
# (1, 2, 4, 4, 8, 0)
# cost time 5.619816999999955
# terminated node: 0
# reached depth: 8
# (3, 4, 3, 6, 6, 4)
# cost time 4.800324999999987
# terminated node: 0
# reached depth: 8
# (1, 4, 3, 5, 6, 3)
# cost time 5.099176999999997
# terminated node: 0
# reached depth: 8
# (2, 3, 2, 3, 5, 0)
# cost time 5.017861000000039
# terminated node: 0
# reached depth: 8
# (3, 4, 2, 7, 6, 7)
# cost time 5.445871000000011
# terminated node: 0
# reached depth: 8
# (1, 3, 4, 3, 7, 2)
# cost time 4.234789999999975
# terminated node: 0
# reached depth: 8
# (2, 2, 3, 7, 4, 0)
# cost time 5.146856000000014
# terminated node: 0
# reached depth: 8
# (3, 5, 4, 0, 5, 4)
# cost time 5.430983000000026
# terminated node: 0
# reached depth: 8
# (2, 4, 3, 5, 6, 7)
# cost time 4.777556000000004
# terminated node: 0
# reached depth: 8
# (2, 5, 3, 3, 5, 6)
# cost time 4.998354000000006
# terminated node: 0
# reached depth: 8
# (2, 4, 5, 8, 0, 0)
# cost time 4.510873000000004
# terminated node: 0
# reached depth: 8
# (2, 4, 2, 0, 6, 8)
# cost time 4.786004999999989
# terminated node: 0
# reached depth: 8
# (3, 4, 3, 5, 0, 0)
# cost time 4.677588000000014
# terminated node: 0
# reached depth: 8
# (4, 5, 1, 1, 0, 0)
# cost time 4.707224999999994
# terminated node: 0
# reached depth: 8
# (1, 5, 5, 0, 0, 0)
# cost time 4.8108290000000125
# terminated node: 0
# reached depth: 8
# (2, 3, 4, 8, 3, 5)
# cost time 4.22342900000001
# terminated node: 0
# reached depth: 8
# (3, 3, 1, 7, 7, 9)
# cost time 4.851287999999954
# terminated node: 0
# reached depth: 8
# (1, 5, 4, 7, 1, 3)
# cost time 4.728495000000009
# terminated node: 0
# reached depth: 8
# (1, 1, 4, 6, 4, 0)
# cost time 4.663412999999991
# terminated node: 0
# reached depth: 8
# (2, 2, 4, 3, 3, 1)
# cost time 3.8594380000000115
# terminated node: 0
# reached depth: 8
# (2, 5, 4, 1, 0, 1)
# cost time 3.762808000000007
# terminated node: 2
# reached depth: 7
# (2, 3, 5, 8, 0, 5)
# cost time 2.6635499999999865
# terminated node: 4
# reached depth: 6
# (3, 5, 4, 4, 0, 5)
# cost time 1.6841640000000098
# terminated node: 32
# reached depth: 5
# (1, 1, 3, 5, 5, 0)
# cost time 1.505531000000019
# terminated node: 32
# reached depth: 4
# (4, 5, 2, 0, 0, 5)
# cost time 1.0868970000000218
# terminated node: 35
# reached depth: 3
# (2, 5, 2, 0, 1, 8)
# cost time 0.5848259999999641
# terminated node: 47
# reached depth: 2
# (2, 2, 1, 8, 5, 9)
# cost time 0.46889300000003686
# terminated node: 48
# reached depth: 1
# (2, 5, 2, 2, 0, 7)
# cost time 0.41400700000002644
# terminated node: 49
# reached depth: 0
# (3, 4, 3, 0, 0, 10)
# [0.802, 34, 8.02]
# cost time 3.158836000000008
# terminated node: 0
# reached depth: 8
# (1, 3, 3, 0, 7, 0)
# cost time 4.714197000000013
# terminated node: 0
# reached depth: 8
# (1, 4, 3, 0, 6, 3)
# cost time 4.6710259999999835
# terminated node: 0
# reached depth: 8
# (1, 3, 5, 9, 7, 0)
# cost time 5.211298999999997
# terminated node: 0
# reached depth: 8
# (2, 5, 1, 7, 5, 0)
# cost time 5.251974999999959
# terminated node: 0
# reached depth: 8
# (1, 3, 2, 9, 4, 0)
# cost time 5.181793000000027
# terminated node: 0
# reached depth: 8
# (2, 4, 2, 7, 6, 1)
# cost time 5.1581710000000385
# terminated node: 0
# reached depth: 8
# (3, 5, 4, 1, 5, 0)
# cost time 4.1455760000000055
# terminated node: 0
# reached depth: 8
# (2, 5, 1, 4, 5, 0)
# cost time 4.394300000000044
# terminated node: 0
# reached depth: 8
# (1, 3, 1, 6, 7, 0)
# cost time 3.8206440000000157
# terminated node: 0
# reached depth: 8
# (3, 3, 2, 4, 7, 1)
# cost time 4.652822000000015
# terminated node: 0
# reached depth: 8
# (1, 1, 3, 6, 6, 0)
# cost time 4.303974000000039
# terminated node: 0
# reached depth: 8
# (2, 5, 2, 7, 5, 3)
# cost time 4.73988700000001
# terminated node: 0
# reached depth: 8
# (1, 3, 2, 9, 7, 5)
# cost time 4.93593199999998
# terminated node: 0
# reached depth: 8
# (2, 4, 2, 4, 6, 3)
# cost time 5.125892000000022
# terminated node: 0
# reached depth: 8
# (1, 3, 5, 6, 7, 3)
# cost time 5.492942000000028
# terminated node: 0
# reached depth: 8
# (2, 4, 3, 7, 6, 5)
# cost time 4.799063999999987
# terminated node: 0
# reached depth: 8
# (1, 5, 1, 9, 5, 7)
# cost time 4.10176100000001
# terminated node: 0
# reached depth: 8
# (2, 3, 3, 2, 7, 4)
# cost time 4.077095999999983
# terminated node: 0
# reached depth: 8
# (4, 5, 3, 0, 5, 7)
# cost time 3.8425790000000006
# terminated node: 0
# reached depth: 8
# (2, 3, 1, 8, 7, 8)
# cost time 4.069662999999991
# terminated node: 0
# reached depth: 8
# (2, 4, 4, 4, 6, 5)
# cost time 4.075109999999995
# terminated node: 0
# reached depth: 8
# (4, 3, 1, 6, 7, 9)
# cost time 4.196926000000019
# terminated node: 0
# reached depth: 8
# (1, 4, 1, 9, 3, 8)
# cost time 5.12314200000003
# terminated node: 0
# reached depth: 8
# (1, 5, 4, 8, 0, 0)
# cost time 4.821179000000029
# terminated node: 0
# reached depth: 8
# (4, 4, 4, 4, 0, 0)
# cost time 4.709304999999972
# terminated node: 0
# reached depth: 8
# (4, 4, 2, 0, 1, 0)
# cost time 4.125872000000015
# terminated node: 0
# reached depth: 8
# (1, 3, 1, 9, 0, 0)
# cost time 3.4847489999999652
# terminated node: 0
# reached depth: 8
# (1, 1, 4, 6, 5, 0)
# cost time 3.582177999999999
# terminated node: 0
# reached depth: 8
# (1, 5, 4, 8, 1, 5)
# cost time 3.3233390000000327
# terminated node: 0
# reached depth: 8
# (2, 1, 5, 6, 4, 0)
# cost time 2.6912139999999454
# terminated node: 5
# reached depth: 7
# (3, 2, 4, 5, 4, 5)
# cost time 2.5531619999999293
# terminated node: 15
# reached depth: 6
# (2, 3, 3, 6, 1, 4)
# cost time 1.8594630000000052
# terminated node: 19
# reached depth: 5
# (3, 3, 1, 7, 4, 9)
# cost time 1.934037000000103
# terminated node: 20
# reached depth: 4
# (4, 5, 5, 0, 0, 2)
# cost time 0.9380610000000615
# terminated node: 45
# reached depth: 3
# (4, 1, 5, 6, 0, 4)
# cost time 0.6821489999999812
# terminated node: 48
# reached depth: 1
# (5, 3, 3, 3, 1, 7)
# cost time 0.6283170000000382
# terminated node: 49
# reached depth: 0
# (4, 2, 5, 0, 0, 10)
# [0.749, 36, 7.49]
# cost time 4.237393999999995
# terminated node: 0
# reached depth: 8
# (3, 5, 4, 0, 5, 0)
# cost time 4.2087340000000495
# terminated node: 0
# reached depth: 8
# (1, 1, 2, 9, 9, 0)
# cost time 5.4225830000000315
# terminated node: 0
# reached depth: 8
# (3, 4, 4, 6, 6, 0)
# cost time 4.877446999999961
# terminated node: 0
# reached depth: 8
# (1, 5, 2, 9, 4, 0)
# cost time 4.725746000000072
# terminated node: 0
# reached depth: 8
# (2, 1, 5, 4, 9, 0)
# cost time 5.43285400000002
# terminated node: 0
# reached depth: 8
# (3, 5, 3, 3, 4, 0)
# cost time 4.788834999999949
# terminated node: 0
# reached depth: 8
# (3, 1, 5, 6, 5, 0)
# cost time 4.308519000000047
# terminated node: 0
# reached depth: 8
# (1, 5, 3, 9, 5, 2)
# cost time 5.250374999999963
# terminated node: 0
# reached depth: 8
# (2, 4, 3, 7, 6, 4)
# cost time 5.138426999999979
# terminated node: 0
# reached depth: 8
# (1, 4, 3, 9, 6, 5)
# cost time 5.312531000000035
# terminated node: 0
# reached depth: 8
# (1, 5, 5, 9, 0, 2)
# cost time 5.1588879999999335
# terminated node: 0
# reached depth: 8
# (2, 5, 4, 6, 0, 0)
# cost time 5.223930999999993
# terminated node: 0
# reached depth: 8
# (2, 3, 3, 7, 7, 7)
# cost time 5.418897000000015
# terminated node: 0
# reached depth: 8
# (3, 5, 4, 0, 0, 0)
# cost time 4.710669999999936
# terminated node: 0
# reached depth: 8
# (2, 4, 4, 5, 6, 5)
# cost time 5.527241000000004
# terminated node: 0
# reached depth: 8
# (1, 5, 4, 8, 0, 0)
# cost time 5.469270000000051
# terminated node: 0
# reached depth: 8
# (3, 5, 3, 0, 5, 4)
# cost time 4.315979999999968
# terminated node: 0
# reached depth: 8
# (1, 5, 1, 9, 5, 8)
# cost time 5.206748999999945
# terminated node: 0
# reached depth: 8
# (1, 5, 5, 3, 5, 3)
# cost time 5.411915999999906
# terminated node: 0
# reached depth: 8
# (3, 4, 5, 3, 0, 0)
# cost time 5.253744999999981
# terminated node: 0
# reached depth: 8
# (2, 4, 1, 5, 6, 9)
# cost time 4.793586000000005
# terminated node: 0
# reached depth: 8
# (1, 5, 4, 4, 5, 5)
# cost time 4.031823999999915
# terminated node: 0
# reached depth: 8
# (2, 3, 2, 7, 4, 7)
# cost time 4.846080999999913
# terminated node: 0
# reached depth: 8
# (2, 5, 5, 5, 0, 5)
# cost time 3.5701669999999694
# terminated node: 0
# reached depth: 8
# (2, 5, 1, 8, 2, 9)
# cost time 4.177413999999999
# terminated node: 0
# reached depth: 8
# (2, 3, 3, 1, 7, 7)
# cost time 3.544251000000031
# terminated node: 0
# reached depth: 8
# (1, 1, 4, 5, 5, 3)
# cost time 3.8271389999999883
# terminated node: 0
# reached depth: 8
# (1, 4, 1, 4, 6, 9)
# cost time 4.177773999999999
# terminated node: 0
# reached depth: 8
# (1, 2, 1, 7, 5, 9)
# cost time 4.168006999999989
# terminated node: 0
# reached depth: 8
# (2, 5, 3, 0, 2, 7)
# cost time 3.0000890000000027
# terminated node: 0
# reached depth: 8
# (1, 3, 2, 3, 7, 8)
# cost time 1.9091549999999415
# terminated node: 30
# reached depth: 7
# (1, 2, 4, 8, 0, 4)
# cost time 2.134590000000003
# terminated node: 31
# reached depth: 6
# (1, 2, 3, 0, 8, 7)
# cost time 1.8833900000000767
# terminated node: 32
# reached depth: 5
# (2, 5, 4, 3, 0, 5)
# cost time 1.0358770000000277
# terminated node: 45
# reached depth: 4
# (1, 4, 3, 7, 0, 4)
# cost time 0.9787950000001047
# terminated node: 46
# reached depth: 3
# (1, 2, 1, 9, 8, 9)
# cost time 0.8886270000000422
# terminated node: 47
# reached depth: 2
# (1, 3, 3, 7, 0, 7)
# cost time 0.6519779999999855
# terminated node: 48
# reached depth: 1
# (1, 5, 3, 2, 0, 4)
# cost time 0.6560939999999391
# terminated node: 49
# reached depth: 0
# (5, 5, 5, 0, 0, 10)
# [0.827, 38, 8.27]
# cost time 4.776376999999911
# terminated node: 0
# reached depth: 8
# (1, 2, 1, 0, 8, 0)
# cost time 5.273234000000002
# terminated node: 0
# reached depth: 8
# (1, 2, 3, 9, 8, 0)
# cost time 6.272711999999956
# terminated node: 0
# reached depth: 8
# (2, 4, 5, 7, 6, 0)
# cost time 6.003649999999993
# terminated node: 0
# reached depth: 8
# (2, 3, 3, 5, 7, 0)
# cost time 5.539180999999985
# terminated node: 0
# reached depth: 8
# (1, 4, 1, 9, 6, 3)
# cost time 6.464740000000006
# terminated node: 0
# reached depth: 8
# (3, 5, 1, 1, 5, 0)
# cost time 6.332728999999972
# terminated node: 0
# reached depth: 8
# (2, 4, 4, 3, 6, 1)
# cost time 6.427825999999982
# terminated node: 0
# reached depth: 8
# (3, 4, 5, 0, 6, 1)
# cost time 5.877446000000077
# terminated node: 0
# reached depth: 8
# (1, 4, 3, 9, 6, 4)
# cost time 6.034456999999975
# terminated node: 0
# reached depth: 8
# (1, 5, 2, 5, 5, 3)
# cost time 6.125462999999968
# terminated node: 0
# reached depth: 8
# (2, 4, 3, 7, 6, 5)
# cost time 6.387145000000032
# terminated node: 0
# reached depth: 8
# (3, 4, 4, 7, 0, 0)
# cost time 5.7368719999999485
# terminated node: 0
# reached depth: 8
# (1, 4, 2, 6, 6, 3)
# cost time 6.121038999999996
# terminated node: 0
# reached depth: 8
# (3, 4, 4, 4, 6, 5)
# cost time 5.796453999999926
# terminated node: 0
# reached depth: 8
# (4, 5, 2, 0, 5, 6)
# cost time 5.714300999999978
# terminated node: 0
# reached depth: 8
# (4, 2, 4, 6, 4, 0)
# cost time 5.771267999999964
# terminated node: 0
# reached depth: 8
# (3, 5, 2, 0, 5, 8)
# cost time 5.74380599999995
# terminated node: 0
# reached depth: 8
# (5, 5, 1, 0, 0, 0)
# cost time 5.446858999999904
# terminated node: 0
# reached depth: 8
# (1, 5, 4, 5, 0, 0)
# cost time 6.390251000000035
# terminated node: 0
# reached depth: 8
# (5, 5, 2, 0, 0, 1)
# cost time 4.624222999999915
# terminated node: 0
# reached depth: 8
# (2, 4, 2, 8, 6, 8)
# cost time 4.27355
# terminated node: 0
# reached depth: 8
# (3, 3, 1, 5, 7, 9)
# cost time 3.6565239999999903
# terminated node: 0
# reached depth: 8
# (1, 3, 3, 6, 1, 0)
# cost time 4.020462000000066
# terminated node: 2
# reached depth: 7
# (1, 4, 5, 9, 2, 4)
# cost time 3.6748580000000857
# terminated node: 3
# reached depth: 6
# (2, 5, 3, 7, 1, 4)
# cost time 2.211184000000003
# terminated node: 19
# reached depth: 5
# (1, 2, 3, 8, 4, 7)
# cost time 1.4706640000000561
# terminated node: 25
# reached depth: 4
# (2, 2, 5, 5, 4, 5)
# cost time 1.3980489999999008
# terminated node: 29
# reached depth: 3
# (3, 5, 3, 0, 0, 3)
# cost time 1.293064999999956
# terminated node: 30
# reached depth: 2
# (5, 5, 4, 0, 0, 6)
# cost time 0.7146940000000086
# terminated node: 48
# reached depth: 1
# (2, 2, 3, 8, 0, 7)
# cost time 0.6364360000000033
# terminated node: 49
# reached depth: 0
# (5, 3, 4, 0, 0, 10)
# [0.791, 30, 7.91]
# cost time 4.086176000000023
# terminated node: 0
# reached depth: 8
# (1, 4, 2, 0, 6, 0)
# cost time 3.7839269999999487
# terminated node: 0
# reached depth: 8
# (1, 5, 4, 0, 5, 2)
# cost time 4.6950689999999895
# terminated node: 0
# reached depth: 8
# (1, 2, 5, 9, 8, 0)
# cost time 6.119397999999933
# terminated node: 0
# reached depth: 8
# (4, 4, 4, 1, 6, 0)
# cost time 5.960574000000065
# terminated node: 0
# reached depth: 8
# (2, 4, 3, 7, 6, 0)
# cost time 5.563523000000032
# terminated node: 0
# reached depth: 8
# (2, 4, 5, 5, 6, 0)
# cost time 6.052130000000034
# terminated node: 0
# reached depth: 8
# (1, 5, 3, 8, 5, 3)
# cost time 5.592636999999968
# terminated node: 0
# reached depth: 8
# (1, 3, 5, 9, 5, 0)
# cost time 6.136157000000026
# terminated node: 0
# reached depth: 8
# (2, 3, 2, 8, 7, 6)
# cost time 5.346483000000035
# terminated node: 0
# reached depth: 7
# (3, 4, 4, 7, 0, 0)
# cost time 5.521898000000078
# terminated node: 0
# reached depth: 7
# (2, 5, 5, 1, 5, 4)
# cost time 5.1294900000000325
# terminated node: 0
# reached depth: 8
# (3, 4, 5, 5, 6, 5)
# cost time 4.8414280000000645
# terminated node: 0
# reached depth: 8
# (3, 2, 5, 5, 4, 0)
# cost time 5.377650000000017
# terminated node: 0
# reached depth: 8
# (4, 5, 3, 0, 0, 0)
# cost time 4.204180999999949
# terminated node: 0
# reached depth: 8
# (2, 3, 4, 5, 0, 0)
# cost time 4.327827999999954
# terminated node: 0
# reached depth: 8
# (1, 1, 3, 9, 4, 0)
# cost time 4.434818000000064
# terminated node: 0
# reached depth: 8
# (1, 4, 4, 4, 6, 4)
# cost time 4.401485999999977
# terminated node: 0
# reached depth: 8
# (1, 5, 3, 3, 5, 4)
# cost time 4.186429000000089
# terminated node: 0
# reached depth: 8
# (1, 5, 4, 0, 5, 6)
# cost time 4.144884999999931
# terminated node: 0
# reached depth: 8
# (1, 1, 1, 8, 4, 0)
# cost time 5.111369999999965
# terminated node: 0
# reached depth: 8
# (2, 5, 3, 8, 2, 6)
# cost time 3.6446789999999964
# terminated node: 0
# reached depth: 8
# (2, 4, 4, 6, 2, 5)
# cost time 3.431846000000064
# terminated node: 0
# reached depth: 8
# (2, 5, 1, 8, 5, 9)
# cost time 3.583643000000052
# terminated node: 5
# reached depth: 7
# (1, 2, 4, 4, 4, 0)
# cost time 2.6030439999999544
# terminated node: 6
# reached depth: 6
# (1, 3, 5, 4, 1, 0)
# cost time 2.359530999999947
# terminated node: 6
# reached depth: 5
# (2, 2, 2, 3, 8, 8)
# cost time 2.3224460000000136
# terminated node: 6
# reached depth: 4
# (3, 5, 5, 0, 0, 3)
# cost time 0.8076419999999871
# terminated node: 46
# reached depth: 3
# (1, 4, 1, 1, 6, 9)
# cost time 0.595203999999967
# terminated node: 47
# reached depth: 2
# (1, 2, 1, 9, 0, 4)
# cost time 0.4827850000000353
# terminated node: 48
# reached depth: 1
# (3, 4, 4, 3, 0, 5)
# cost time 0.4109119999999393
# terminated node: 49
# reached depth: 0
# (4, 4, 3, 0, 0, 9)
# [0.767, 30, 7.67]
# cost time 3.405501000000072
# terminated node: 0
# reached depth: 8
# (1, 5, 1, 0, 5, 0)
# cost time 3.941057999999998
# terminated node: 0
# reached depth: 8
# (1, 1, 5, 9, 9, 0)
# cost time 4.999549999999999
# terminated node: 0
# reached depth: 8
# (3, 4, 4, 0, 6, 1)
# cost time 4.0186840000000075
# terminated node: 0
# reached depth: 8
# (1, 2, 5, 9, 7, 0)
# cost time 4.340309999999931
# terminated node: 0
# reached depth: 8
# (1, 2, 2, 8, 8, 0)
# cost time 5.000163000000043
# terminated node: 0
# reached depth: 8
# (1, 5, 2, 7, 5, 0)
# cost time 4.687389999999937
# terminated node: 0
# reached depth: 8
# (2, 3, 3, 8, 4, 0)
# cost time 5.168556999999964
# terminated node: 0
# reached depth: 8
# (1, 2, 5, 6, 8, 0)
# cost time 5.133170000000064
# terminated node: 0
# reached depth: 7
# (1, 5, 3, 5, 5, 0)
# cost time 5.9641430000000355
# terminated node: 0
# reached depth: 6
# (3, 4, 5, 7, 0, 0)
# cost time 4.201504
# terminated node: 0
# reached depth: 6
# (1, 1, 2, 8, 7, 0)
# cost time 4.819313000000079
# terminated node: 0
# reached depth: 5
# (3, 4, 4, 7, 6, 5)
# cost time 5.024778999999967
# terminated node: 0
# reached depth: 8
# (3, 5, 3, 3, 5, 3)
# cost time 4.929800999999998
# terminated node: 0
# reached depth: 8
# (5, 5, 4, 0, 0, 0)
# cost time 5.113196000000016
# terminated node: 0
# reached depth: 8
# (1, 5, 4, 6, 3, 0)
# cost time 4.437765000000127
# terminated node: 0
# reached depth: 8
# (2, 3, 5, 5, 0, 0)
# cost time 4.193137000000206
# terminated node: 0
# reached depth: 8
# (2, 5, 4, 0, 5, 5)
# cost time 4.370809999999892
# terminated node: 0
# reached depth: 8
# (3, 1, 1, 7, 5, 3)
# cost time 4.355984999999919
# terminated node: 0
# reached depth: 8
# (3, 3, 3, 4, 7, 6)
# cost time 4.14345800000001
# terminated node: 0
# reached depth: 8
# (1, 4, 2, 2, 6, 5)
# cost time 3.8517779999999675
# terminated node: 0
# reached depth: 8
# (3, 4, 4, 7, 2, 5)
# cost time 2.9825559999999314
# terminated node: 0
# reached depth: 8
# (4, 5, 1, 6, 5, 9)
# cost time 2.9025819999999385
# terminated node: 3
# reached depth: 8
# (1, 2, 2, 5, 3, 0)
# cost time 2.4749500000000353
# terminated node: 2
# reached depth: 8
# (3, 5, 3, 4, 0, 5)
# cost time 1.3460009999998874
# terminated node: 29
# reached depth: 5
# (1, 5, 4, 3, 5, 6)
# cost time 1.0303639999999632
# terminated node: 37
# reached depth: 4
# (5, 5, 1, 5, 0, 9)
# cost time 1.0381680000000415
# terminated node: 40
# reached depth: 3
# (2, 5, 5, 0, 0, 4)
# cost time 0.7855340000000979
# terminated node: 44
# reached depth: 2
# (5, 5, 1, 0, 0, 9)
# cost time 0.6919659999998657
# terminated node: 48
# reached depth: 1
# (2, 5, 1, 0, 5, 9)
# cost time 0.6453769999998258
# terminated node: 49
# reached depth: 0
# (2, 4, 4, 0, 0, 10)
# [0.755, 29, 7.55]
# cost time 4.1607749999998305
# terminated node: 0
# reached depth: 8
# (1, 1, 1, 0, 9, 0)
# cost time 4.262216999999964
# terminated node: 0
# reached depth: 8
# (1, 3, 3, 9, 7, 0)
# cost time 4.725560999999971
# terminated node: 0
# reached depth: 8
# (1, 5, 2, 8, 5, 0)
# cost time 4.845802000000049
# terminated node: 0
# reached depth: 8
# (2, 3, 3, 6, 7, 0)
# cost time 5.426005000000032
# terminated node: 0
# reached depth: 8
# (1, 2, 5, 9, 5, 0)
# cost time 5.914780000000064
# terminated node: 0
# reached depth: 6
# (2, 5, 2, 4, 5, 0)
# cost time 5.38708500000007
# terminated node: 0
# reached depth: 7
# (4, 5, 4, 0, 4, 0)
# cost time 5.038031000000046
# terminated node: 0
# reached depth: 8
# (3, 5, 4, 7, 0, 0)
# cost time 4.804022000000032
# terminated node: 0
# reached depth: 8
# (1, 2, 5, 9, 8, 3)
# cost time 4.995965999999953
# terminated node: 0
# reached depth: 8
# (2, 3, 3, 7, 7, 3)
# cost time 4.341132000000016
# terminated node: 0
# reached depth: 8
# (1, 5, 3, 5, 5, 2)
# cost time 4.593739999999798
# terminated node: 0
# reached depth: 8
# (4, 1, 5, 0, 9, 1)
# cost time 4.996239999999943
# terminated node: 0
# reached depth: 8
# (3, 2, 5, 6, 5, 2)
# cost time 4.521938999999975
# terminated node: 0
# reached depth: 8
# (1, 5, 3, 8, 5, 7)
# cost time 5.0752880000000005
# terminated node: 0
# reached depth: 8
# (2, 3, 4, 5, 7, 5)
# cost time 4.759705000000167
# terminated node: 0
# reached depth: 8
# (2, 3, 3, 8, 2, 4)
# cost time 4.8824399999998604
# terminated node: 0
# reached depth: 8
# (1, 4, 3, 7, 6, 7)
# cost time 5.300337000000127
# terminated node: 0
# reached depth: 8
# (2, 5, 2, 5, 0, 0)
# cost time 4.449431999999888
# terminated node: 0
# reached depth: 8
# (3, 5, 2, 0, 4, 4)
# cost time 4.432696999999962
# terminated node: 0
# reached depth: 8
# (1, 5, 2, 9, 3, 7)
# cost time 4.391892000000098
# terminated node: 0
# reached depth: 8
# (1, 4, 1, 4, 6, 2)
# cost time 4.306305000000066
# terminated node: 0
# reached depth: 8
# (2, 5, 5, 5, 0, 2)
# cost time 4.24050699999998
# terminated node: 0
# reached depth: 7
# (3, 5, 4, 0, 5, 6)
# cost time 3.566420999999991
# terminated node: 0
# reached depth: 8
# (1, 2, 4, 4, 8, 3)
# cost time 3.391059000000041
# terminated node: 0
# reached depth: 7
# (5, 2, 5, 0, 0, 0)
# cost time 3.6191919999998845
# terminated node: 2
# reached depth: 6
# (3, 5, 3, 6, 0, 7)
# cost time 3.248931999999968
# terminated node: 2
# reached depth: 5
# (4, 5, 4, 0, 0, 6)
# cost time 0.9638909999998759
# terminated node: 45
# reached depth: 4
# (1, 1, 3, 4, 4, 0)
# cost time 0.8819209999999202
# terminated node: 46
# reached depth: 3
# (1, 3, 3, 4, 5, 3)
# cost time 0.5604800000000978
# terminated node: 47
# reached depth: 2
# (2, 2, 2, 3, 8, 7)
# cost time 0.5616010000001097
# terminated node: 48
# reached depth: 1
# (2, 5, 2, 4, 2, 7)
# cost time 0.5620719999999437
# terminated node: 49
# reached depth: 0
# (2, 5, 3, 0, 0, 10)
# [0.767, 31, 7.67]
# cost time 4.7889590000002045
# terminated node: 0
# reached depth: 8
# (2, 5, 4, 0, 5, 0)
# cost time 4.726973999999927
# terminated node: 0
# reached depth: 8
# (2, 5, 5, 2, 5, 0)
# cost time 4.555100000000039
# terminated node: 0
# reached depth: 8
# (1, 3, 2, 9, 7, 0)
# cost time 4.986630000000105
# terminated node: 0
# reached depth: 8
# (4, 5, 4, 4, 5, 0)
# cost time 3.7310779999997976
# terminated node: 0
# reached depth: 8
# (1, 3, 1, 8, 7, 0)
# cost time 4.332630999999992
# terminated node: 0
# reached depth: 8
# (1, 4, 5, 8, 6, 1)
# cost time 4.108021999999892
# terminated node: 0
# reached depth: 8
# (2, 2, 3, 8, 4, 0)
# cost time 3.7050389999999425
# terminated node: 0
# reached depth: 8
# (1, 4, 3, 9, 6, 2)
# cost time 3.94767499999989
# terminated node: 0
# reached depth: 8
# (2, 5, 3, 0, 5, 4)
# cost time 4.22219999999993
# terminated node: 0
# reached depth: 8
# (2, 3, 3, 6, 7, 4)
# cost time 4.574448999999959
# terminated node: 0
# reached depth: 8
# (1, 3, 4, 8, 7, 6)
# cost time 3.509164999999939
# terminated node: 0
# reached depth: 8
# (1, 4, 3, 5, 6, 4)
# cost time 5.049697000000151
# terminated node: 0
# reached depth: 8
# (2, 2, 2, 8, 4, 3)
# cost time 4.751764000000094
# terminated node: 0
# reached depth: 8
# (1, 1, 5, 9, 9, 5)
# cost time 5.3072819999999865
# terminated node: 0
# reached depth: 8
# (3, 4, 3, 7, 0, 0)
# cost time 4.605953999999883
# terminated node: 0
# reached depth: 8
# (1, 2, 1, 9, 7, 5)
# cost time 5.291148000000021
# terminated node: 0
# reached depth: 8
# (1, 3, 4, 9, 6, 6)
# cost time 5.157375000000002
# terminated node: 0
# reached depth: 8
# (1, 3, 4, 4, 7, 4)
# cost time 5.579786000000013
# terminated node: 0
# reached depth: 8
# (1, 4, 3, 5, 6, 7)
# cost time 6.026342999999997
# terminated node: 0
# reached depth: 8
# (1, 4, 3, 2, 6, 5)
# cost time 6.221136000000115
# terminated node: 0
# reached depth: 8
# (1, 5, 3, 6, 5, 7)
# cost time 5.601987000000008
# terminated node: 0
# reached depth: 8
# (2, 4, 4, 8, 2, 5)
# cost time 4.238900000000058
# terminated node: 0
# reached depth: 8
# (1, 3, 2, 7, 7, 7)
# cost time 5.001365999999962
# terminated node: 0
# reached depth: 8
# (2, 5, 3, 0, 5, 7)
# cost time 4.771093999999948
# terminated node: 0
# reached depth: 8
# (2, 4, 5, 5, 1, 0)
# cost time 4.8738069999999425
# terminated node: 0
# reached depth: 8
# (2, 3, 2, 3, 7, 8)
# cost time 4.388915999999881
# terminated node: 0
# reached depth: 8
# (4, 5, 4, 0, 0, 0)
# cost time 3.251088000000209
# terminated node: 0
# reached depth: 8
# (1, 3, 3, 7, 4, 4)
# cost time 3.0903189999999086
# terminated node: 0
# reached depth: 8
# (1, 4, 3, 7, 3, 7)
# cost time 2.0565930000000208
# terminated node: 25
# reached depth: 7
# (3, 2, 4, 7, 0, 3)
# cost time 2.0715339999999287
# terminated node: 28
# reached depth: 6
# (3, 5, 4, 4, 0, 5)
# cost time 1.742027999999891
# terminated node: 31
# reached depth: 5
# (3, 4, 3, 0, 1, 4)
# cost time 1.5013879999999062
# terminated node: 31
# reached depth: 4
# (4, 5, 2, 0, 0, 7)
# cost time 1.3638320000000022
# terminated node: 31
# reached depth: 3
# (2, 2, 4, 3, 5, 5)
# cost time 1.3151319999999487
# terminated node: 33
# reached depth: 2
# (4, 5, 1, 0, 0, 9)
# cost time 0.7660289999998895
# terminated node: 48
# reached depth: 1
# (1, 3, 2, 2, 7, 8)
# cost time 0.6582999999998265
# terminated node: 49
# reached depth: 0
# (4, 4, 2, 0, 0, 10)
# [0.832, 36, 8.32]
# cost time 4.66641699999991
# terminated node: 0
# reached depth: 8
# (1, 5, 2, 0, 5, 0)
# cost time 4.574317000000065
# terminated node: 0
# reached depth: 8
# (2, 5, 5, 1, 5, 0)
# cost time 4.864554999999882
# terminated node: 0
# reached depth: 8
# (2, 5, 4, 3, 5, 0)
# cost time 4.131648000000041
# terminated node: 0
# reached depth: 8
# (1, 4, 5, 9, 6, 0)
# cost time 4.568723000000091
# terminated node: 0
# reached depth: 8
# (3, 2, 1, 6, 8, 0)
# cost time 5.2487089999999625
# terminated node: 0
# reached depth: 8
# (1, 2, 5, 8, 8, 1)
# cost time 5.031878000000006
# terminated node: 0
# reached depth: 8
# (3, 5, 4, 5, 5, 1)
# cost time 3.493539999999939
# terminated node: 0
# reached depth: 8
# (1, 5, 3, 0, 5, 2)
# cost time 3.0757579999999507
# terminated node: 0
# reached depth: 8
# (1, 2, 2, 8, 6, 0)
# cost time 3.798778000000084
# terminated node: 0
# reached depth: 8
# (1, 5, 1, 9, 5, 5)
# cost time 4.8281070000000454
# terminated node: 0
# reached depth: 8
# (1, 4, 3, 9, 6, 6)
# cost time 4.59039800000005
# terminated node: 0
# reached depth: 8
# (2, 4, 2, 6, 6, 5)
# cost time 5.0416969999998855
# terminated node: 0
# reached depth: 8
# (1, 2, 1, 8, 6, 2)
# cost time 4.917374000000109
# terminated node: 0
# reached depth: 8
# (1, 5, 3, 8, 5, 6)
# cost time 4.553612000000157
# terminated node: 0
# reached depth: 8
# (2, 4, 1, 6, 6, 7)
# cost time 5.137698999999884
# terminated node: 0
# reached depth: 8
# (4, 5, 5, 6, 0, 0)
# cost time 4.386014000000159
# terminated node: 0
# reached depth: 8
# (2, 4, 4, 3, 6, 4)
# cost time 4.3228129999999965
# terminated node: 0
# reached depth: 8
# (2, 4, 1, 8, 6, 9)
# cost time 3.9578149999999823
# terminated node: 0
# reached depth: 8
# (3, 4, 3, 0, 6, 5)
# cost time 4.095044000000144
# terminated node: 0
# reached depth: 8
# (3, 4, 2, 5, 6, 8)
# cost time 3.9625610000000506
# terminated node: 0
# reached depth: 8
# (1, 5, 5, 9, 0, 5)
# cost time 4.5068310000001475
# terminated node: 0
# reached depth: 8
# (1, 5, 1, 4, 5, 8)
# cost time 4.829698000000008
# terminated node: 0
# reached depth: 8
# (1, 4, 2, 8, 1, 5)
# cost time 4.647701999999981
# terminated node: 0
# reached depth: 8
# (3, 4, 2, 1, 6, 8)
# cost time 4.530308000000105
# terminated node: 0
# reached depth: 8
# (1, 3, 4, 7, 3, 5)
# cost time 4.134156999999959
# terminated node: 0
# reached depth: 8
# (2, 4, 4, 4, 1, 0)
# cost time 3.849578000000065
# terminated node: 0
# reached depth: 8
# (3, 5, 2, 0, 0, 0)
# cost time 3.85040099999992
# terminated node: 7
# reached depth: 7
# (4, 5, 3, 0, 0, 2)
# cost time 2.144498999999996
# terminated node: 24
# reached depth: 7
# (1, 4, 5, 6, 2, 5)
# cost time 1.4440300000001116
# terminated node: 36
# reached depth: 5
# (1, 4, 2, 8, 1, 7)
# cost time 1.4737700000000586
# terminated node: 36
# reached depth: 4
# (1, 4, 4, 5, 0, 4)
# cost time 1.0875169999999343
# terminated node: 39
# reached depth: 3
# (1, 5, 5, 4, 0, 4)
# cost time 0.8385990000001584
# terminated node: 47
# reached depth: 2
# (3, 4, 4, 0, 2, 5)
# cost time 0.6211720000001151
# terminated node: 48
# reached depth: 1
# (4, 2, 5, 0, 0, 5)
# cost time 0.6562800000001516
# terminated node: 49
# reached depth: 0
# (3, 4, 2, 0, 0, 10)
# [0.826, 34, 8.26]
# cost time 4.629462000000103
# terminated node: 0
# reached depth: 8
# (2, 5, 4, 0, 5, 0)
# cost time 5.067207000000053
# terminated node: 0
# reached depth: 8
# (2, 2, 5, 8, 8, 0)
# cost time 5.09314100000006
# terminated node: 0
# reached depth: 8
# (1, 3, 5, 9, 5, 0)
# cost time 4.8301020000001245
# terminated node: 0
# reached depth: 8
# (2, 2, 5, 6, 8, 0)
# cost time 5.236853999999994
# terminated node: 0
# reached depth: 8
# (2, 3, 5, 7, 5, 0)
# cost time 5.132727999999815
# terminated node: 0
# reached depth: 8
# (4, 5, 5, 2, 5, 0)
# cost time 4.192001000000118
# terminated node: 0
# reached depth: 8
# (1, 2, 4, 6, 6, 0)
# cost time 4.285679999999957
# terminated node: 0
# reached depth: 8
# (2, 5, 4, 8, 5, 5)
# cost time 3.4005839999999807
# terminated node: 0
# reached depth: 8
# (2, 4, 2, 6, 6, 5)
# cost time 3.088960000000043
# terminated node: 0
# reached depth: 8
# (1, 5, 2, 7, 5, 7)
# cost time 3.698075999999901
# terminated node: 0
# reached depth: 8
# (1, 5, 1, 9, 5, 9)
# cost time 3.623139999999921
# terminated node: 0
# reached depth: 8
# (1, 5, 1, 8, 5, 9)
# cost time 4.862255000000005
# terminated node: 0
# reached depth: 8
# (1, 4, 3, 6, 6, 7)
# cost time 4.287698000000091
# terminated node: 0
# reached depth: 8
# (1, 5, 1, 7, 5, 9)
# cost time 4.689941999999974
# terminated node: 0
# reached depth: 8
# (1, 1, 3, 9, 4, 0)
# cost time 3.975206999999955
# terminated node: 0
# reached depth: 8
# (2, 2, 3, 8, 2, 0)
# cost time 4.2345399999999245
# terminated node: 0
# reached depth: 7
# (3, 4, 4, 0, 6, 5)
# cost time 4.423579000000018
# terminated node: 0
# reached depth: 8
# (3, 5, 5, 3, 5, 5)
# cost time 3.3296419999999216
# terminated node: 0
# reached depth: 8
# (1, 5, 4, 9, 0, 3)
# cost time 3.629623000000038
# terminated node: 1
# reached depth: 7
# (2, 5, 3, 6, 0, 0)
# cost time 2.9216959999998835
# terminated node: 5
# reached depth: 6
# (1, 5, 3, 9, 0, 7)
# cost time 2.8475519999999506
# terminated node: 6
# reached depth: 5
# (2, 2, 2, 7, 3, 3)
# cost time 2.540767000000187
# terminated node: 6
# reached depth: 4
# (5, 5, 4, 0, 0, 0)
# cost time 2.16871900000001
# terminated node: 9
# reached depth: 3
# (3, 4, 4, 6, 1, 5)
# cost time 1.1106009999998605
# terminated node: 35
# reached depth: 2
# (2, 5, 4, 4, 0, 4)
# cost time 0.518098000000009
# terminated node: 48
# reached depth: 1
# (4, 5, 3, 0, 0, 4)
# cost time 0.467583999999988
# terminated node: 49
# reached depth: 0
# (5, 4, 4, 0, 0, 8)
# [0.785, 26, 7.8500000000000005]
# cost time 4.9803730000001
# terminated node: 0
# reached depth: 8
# (1, 5, 1, 0, 5, 0)
# cost time 4.051555000000008
# terminated node: 0
# reached depth: 8
# (1, 1, 5, 9, 9, 0)
# cost time 5.029500000000098
# terminated node: 0
# reached depth: 8
# (3, 5, 5, 0, 5, 1)
# cost time 4.163610000000062
# terminated node: 0
# reached depth: 8
# (2, 4, 3, 7, 6, 0)
# cost time 4.532043999999814
# terminated node: 0
# reached depth: 8
# (1, 5, 4, 3, 5, 0)
# cost time 4.440677999999934
# terminated node: 0
# reached depth: 8
# (1, 2, 2, 9, 7, 0)
# cost time 5.1431760000000395
# terminated node: 0
# reached depth: 8
# (3, 2, 5, 4, 8, 0)
# cost time 4.750454999999874
# terminated node: 0
# reached depth: 8
# (1, 4, 4, 9, 5, 2)
# cost time 4.787439000000177
# terminated node: 0
# reached depth: 8
# (2, 2, 3, 7, 8, 3)
# cost time 5.594843000000083
# terminated node: 0
# reached depth: 8
# (2, 5, 4, 8, 0, 0)
# cost time 4.631221000000096
# terminated node: 0
# reached depth: 8
# (1, 2, 4, 6, 6, 0)
# cost time 5.161811999999827
# terminated node: 0
# reached depth: 8
# (2, 5, 5, 4, 3, 0)
# cost time 4.868574999999964
# terminated node: 0
# reached depth: 8
# (2, 3, 4, 8, 7, 6)
# cost time 5.163045000000011
# terminated node: 0
# reached depth: 8
# (2, 4, 3, 6, 6, 6)
# cost time 5.540790000000015
# terminated node: 0
# reached depth: 8
# (4, 5, 3, 0, 0, 0)
# cost time 5.149620999999797
# terminated node: 0
# reached depth: 8
# (2, 2, 5, 6, 4, 0)
# cost time 4.019733999999971
# terminated node: 0
# reached depth: 8
# (1, 4, 5, 7, 0, 0)
# cost time 3.7630330000001777
# terminated node: 0
# reached depth: 8
# (2, 3, 3, 5, 0, 0)
# cost time 3.350174000000152
# terminated node: 0
# reached depth: 8
# (1, 3, 2, 8, 4, 4)
# cost time 3.049052999999958
# terminated node: 0
# reached depth: 8
# (1, 3, 4, 9, 2, 4)
# cost time 3.5064209999998184
# terminated node: 0
# reached depth: 8
# (1, 3, 2, 9, 4, 8)
# cost time 3.0477739999998903
# terminated node: 9
# reached depth: 7
# (1, 4, 3, 3, 6, 4)
# cost time 2.6700439999999617
# terminated node: 10
# reached depth: 6
# (1, 5, 5, 5, 5, 5)
# cost time 2.268691000000217
# terminated node: 11
# reached depth: 5
# (4, 5, 5, 0, 0, 3)
# cost time 2.305262999999968
# terminated node: 11
# reached depth: 4
# (5, 5, 4, 4, 0, 6)
# cost time 1.7139360000001034
# terminated node: 14
# reached depth: 3
# (3, 4, 4, 0, 6, 6)
# cost time 0.7803660000001855
# terminated node: 47
# reached depth: 2
# (1, 1, 4, 8, 6, 6)
# cost time 0.7161519999999655
# terminated node: 48
# reached depth: 1
# (2, 4, 3, 3, 6, 7)
# cost time 0.603507000000036
# terminated node: 49
# reached depth: 0
# (5, 4, 3, 0, 0, 10)
# [0.792, 28, 7.92]
# cost time 3.340102999999999
# terminated node: 0
# reached depth: 8
# (3, 5, 4, 0, 5, 0)
# cost time 5.066718999999921
# terminated node: 0
# reached depth: 8
# (1, 1, 1, 9, 9, 0)
# cost time 4.725789999999961
# terminated node: 0
# reached depth: 8
# (2, 2, 5, 8, 7, 0)
# cost time 4.9450500000000375
# terminated node: 0
# reached depth: 8
# (1, 1, 3, 9, 9, 1)
# cost time 5.1947710000001734
# terminated node: 0
# reached depth: 8
# (1, 3, 4, 9, 4, 0)
# cost time 5.268236000000115
# terminated node: 0
# reached depth: 8
# (1, 1, 3, 8, 9, 0)
# cost time 5.1556940000000395
# terminated node: 0
# reached depth: 7
# (5, 5, 4, 3, 5, 0)
# cost time 4.886402999999973
# terminated node: 0
# reached depth: 7
# (1, 2, 4, 9, 8, 5)
# cost time 5.088220999999976
# terminated node: 0
# reached depth: 6
# (3, 4, 4, 7, 0, 0)
# cost time 5.200559000000112
# terminated node: 0
# reached depth: 7
# (1, 1, 3, 8, 6, 0)
# cost time 4.780062999999927
# terminated node: 0
# reached depth: 6
# (3, 4, 4, 5, 6, 4)
# cost time 5.505534000000125
# terminated node: 0
# reached depth: 6
# (3, 5, 5, 0, 5, 4)
# cost time 4.8576459999999315
# terminated node: 0
# reached depth: 7
# (1, 4, 4, 8, 6, 5)
# cost time 4.7557869999998275
# terminated node: 0
# reached depth: 7
# (4, 5, 3, 0, 0, 0)
# cost time 4.447010999999975
# terminated node: 0
# reached depth: 8
# (2, 3, 4, 3, 7, 4)
# cost time 4.521171999999979
# terminated node: 0
# reached depth: 8
# (4, 5, 4, 6, 0, 4)
# cost time 3.890715999999884
# terminated node: 0
# reached depth: 8
# (2, 5, 4, 4, 0, 0)
# cost time 2.9962910000001557
# terminated node: 0
# reached depth: 8
# (2, 4, 2, 6, 6, 8)
# cost time 2.5086690000000544
# terminated node: 0
# reached depth: 8
# (4, 5, 2, 6, 1, 8)
# cost time 2.2038629999999557
# terminated node: 23
# reached depth: 7
# (2, 4, 4, 4, 2, 4)
# cost time 1.3043500000001131
# terminated node: 36
# reached depth: 6
# (2, 2, 2, 4, 8, 8)
# cost time 1.0034400000001824
# terminated node: 37
# reached depth: 5
# (3, 3, 1, 0, 7, 9)
# cost time 0.8300469999999223
# terminated node: 38
# reached depth: 4
# (1, 1, 5, 9, 6, 4)
# cost time 0.7251999999998588
# terminated node: 39
# reached depth: 3
# (4, 5, 5, 0, 0, 3)
# cost time 0.581327999999985
# terminated node: 45
# reached depth: 2
# (4, 5, 2, 0, 0, 8)
# cost time 0.4491210000001047
# terminated node: 48
# reached depth: 1
# (2, 4, 2, 4, 4, 8)
# cost time 0.40324599999985367
# terminated node: 49
# reached depth: 0
# (4, 2, 4, 0, 0, 10)
# [0.867, 26, 8.67]
# cost time 4.616914999999835
# terminated node: 0
# reached depth: 6
# (3, 5, 5, 0, 5, 0)
# cost time 4.745877000000064
# terminated node: 0
# reached depth: 7
# (4, 5, 4, 3, 5, 0)
# cost time 4.680626999999959
# terminated node: 0
# reached depth: 8
# (2, 5, 5, 8, 5, 0)
# cost time 4.67145000000005
# terminated node: 0
# reached depth: 8
# (3, 5, 4, 7, 0, 0)
# cost time 4.5563099999999395
# terminated node: 0
# reached depth: 8
# (1, 4, 4, 7, 6, 0)
# cost time 4.458834000000024
# terminated node: 0
# reached depth: 8
# (1, 1, 2, 7, 5, 0)
# cost time 5.061294999999973
# terminated node: 0
# reached depth: 8
# (2, 4, 5, 8, 6, 5)
# cost time 4.345007000000123
# terminated node: 0
# reached depth: 8
# (1, 4, 1, 7, 6, 4)
# cost time 4.658672999999908
# terminated node: 0
# reached depth: 8
# (3, 4, 4, 5, 6, 5)
# cost time 3.602578999999878
# terminated node: 0
# reached depth: 8
# (1, 4, 3, 4, 6, 4)
# cost time 3.7430109999997967
# terminated node: 0
# reached depth: 8
# (1, 5, 1, 3, 5, 4)
# cost time 3.698449999999866
# terminated node: 0
# reached depth: 8
# (1, 4, 3, 4, 6, 7)
# cost time 4.12877299999991
# terminated node: 0
# reached depth: 8
# (2, 2, 2, 8, 4, 5)
# cost time 4.136363999999958
# terminated node: 0
# reached depth: 8
# (2, 5, 2, 0, 5, 5)
# cost time 4.661640999999918
# terminated node: 0
# reached depth: 8
# (2, 4, 3, 2, 6, 5)
# cost time 4.857279000000062
# terminated node: 0
# reached depth: 8
# (2, 3, 2, 0, 7, 7)
# cost time 4.415222999999969
# terminated node: 0
# reached depth: 8
# (1, 5, 5, 6, 0, 0)
# cost time 5.880634999999984
# terminated node: 0
# reached depth: 8
# (2, 5, 4, 4, 0, 0)
# cost time 5.004402999999911
# terminated node: 0
# reached depth: 8
# (2, 2, 1, 6, 8, 9)
# cost time 5.563800999999785
# terminated node: 0
# reached depth: 8
# (2, 5, 5, 0, 0, 0)
# cost time 4.6553610000000845
# terminated node: 0
# reached depth: 8
# (1, 1, 2, 7, 5, 2)
# cost time 4.281766999999945
# terminated node: 0
# reached depth: 8
# (3, 4, 5, 7, 0, 4)
# cost time 2.7697820000000775
# terminated node: 0
# reached depth: 8
# (1, 1, 3, 7, 5, 4)
# cost time 3.034091000000217
# terminated node: 11
# reached depth: 8
# (1, 4, 1, 5, 6, 9)
# cost time 2.582630999999992
# terminated node: 27
# reached depth: 7
# (1, 4, 4, 3, 1, 0)
# cost time 2.3149879999998575
# terminated node: 13
# reached depth: 5
# (5, 2, 3, 5, 4, 7)
# cost time 1.8457579999999325
# terminated node: 17
# reached depth: 4
# (1, 5, 4, 2, 0, 0)
# cost time 1.5279680000001008
# terminated node: 28
# reached depth: 3
# (2, 1, 1, 6, 7, 9)
# cost time 1.262030999999979
# terminated node: 29
# reached depth: 2
# (2, 3, 5, 5, 1, 5)
# cost time 0.516456000000062
# terminated node: 48
# reached depth: 1
# (3, 4, 4, 2, 0, 4)
# cost time 0.5759550000000218
# terminated node: 49
# reached depth: 0
# (5, 4, 3, 0, 0, 8)
# [0.802, 30, 8.02]
# cost time 4.032727000000023
# terminated node: 0
# reached depth: 8
# (1, 3, 3, 0, 7, 0)
# cost time 4.2085910000000695
# terminated node: 0
# reached depth: 8
# (1, 5, 4, 1, 5, 0)
# cost time 4.412094999999908
# terminated node: 0
# reached depth: 8
# (2, 4, 2, 8, 6, 0)
# cost time 5.526833000000124
# terminated node: 0
# reached depth: 8
# (1, 5, 1, 7, 5, 0)
# cost time 5.382820999999922
# terminated node: 0
# reached depth: 8
# (1, 3, 4, 6, 7, 0)
# cost time 4.946641
# terminated node: 0
# reached depth: 7
# (1, 5, 3, 5, 5, 0)
# cost time 5.351044000000002
# terminated node: 0
# reached depth: 7
# (3, 4, 4, 2, 6, 0)
# cost time 5.528211000000056
# terminated node: 0
# reached depth: 8
# (1, 4, 5, 9, 6, 2)
# cost time 5.481525000000147
# terminated node: 0
# reached depth: 8
# (4, 5, 5, 6, 0, 0)
# cost time 4.7400639999998475
# terminated node: 0
# reached depth: 8
# (1, 4, 2, 8, 6, 2)
# cost time 5.016651000000138
# terminated node: 0
# reached depth: 8
# (2, 5, 3, 7, 5, 4)
# cost time 5.0864319999998315
# terminated node: 0
# reached depth: 8
# (1, 2, 3, 6, 5, 0)
# cost time 4.631290999999919
# terminated node: 0
# reached depth: 8
# (1, 4, 2, 9, 6, 7)
# cost time 4.817948999999999
# terminated node: 0
# reached depth: 8
# (2, 5, 4, 5, 5, 4)
# cost time 4.7869080000000395
# terminated node: 0
# reached depth: 8
# (1, 2, 3, 8, 8, 7)
# cost time 4.525831000000153
# terminated node: 0
# reached depth: 8
# (2, 5, 5, 0, 5, 4)
# cost time 3.932800000000043
# terminated node: 0
# reached depth: 8
# (2, 4, 2, 3, 6, 4)
# cost time 4.474197000000004
# terminated node: 0
# reached depth: 8
# (2, 3, 2, 6, 7, 8)
# cost time 3.9487060000001293
# terminated node: 0
# reached depth: 8
# (1, 4, 5, 2, 6, 4)
# cost time 4.372234000000162
# terminated node: 0
# reached depth: 8
# (1, 3, 3, 4, 7, 6)
# cost time 4.162589000000025
# terminated node: 0
# reached depth: 8
# (5, 5, 1, 0, 0, 0)
# cost time 4.546610000000101
# terminated node: 0
# reached depth: 8
# (1, 5, 3, 8, 3, 7)
# cost time 4.724744999999984
# terminated node: 0
# reached depth: 8
# (3, 5, 3, 0, 0, 1)
# cost time 2.9524720000001707
# terminated node: 0
# reached depth: 8
# (2, 3, 4, 3, 3, 1)
# cost time 2.936224999999922
# terminated node: 0
# reached depth: 8
# (1, 5, 3, 5, 0, 0)
# cost time 2.5582010000000537
# terminated node: 23
# reached depth: 7
# (3, 5, 1, 0, 5, 9)
# cost time 2.074331999999913
# terminated node: 25
# reached depth: 6
# (1, 5, 4, 3, 5, 6)
# cost time 1.694050999999945
# terminated node: 29
# reached depth: 5
# (1, 2, 2, 5, 8, 8)
# cost time 1.2122799999999643
# terminated node: 30
# reached depth: 4
# (2, 3, 4, 8, 0, 5)
# cost time 0.8381959999999253
# terminated node: 38
# reached depth: 3
# (2, 3, 3, 3, 0, 1)
# cost time 0.5835470000001806
# terminated node: 46
# reached depth: 2
# (4, 5, 5, 0, 0, 5)
# cost time 0.4963199999999688
# terminated node: 48
# reached depth: 1
# (2, 5, 5, 6, 0, 5)
# cost time 0.43796500000007654
# terminated node: 49
# reached depth: 0
# (5, 3, 5, 0, 0, 10)
# [0.805, 32, 8.05]
# cost time 3.3415480000001025
# terminated node: 0
# reached depth: 8
# (2, 2, 2, 0, 8, 0)
# cost time 3.4391259999999875
# terminated node: 0
# reached depth: 8
# (1, 4, 2, 9, 6, 0)
# cost time 4.363840000000209
# terminated node: 0
# reached depth: 8
# (2, 3, 3, 7, 7, 0)
# cost time 4.744726000000128
# terminated node: 0
# reached depth: 8
# (1, 4, 1, 6, 6, 0)
# cost time 3.874567999999954
# terminated node: 0
# reached depth: 8
# (2, 2, 5, 4, 8, 0)
# cost time 4.886632000000191
# terminated node: 0
# reached depth: 8
# (2, 4, 3, 8, 6, 3)
# cost time 4.955367000000024
# terminated node: 0
# reached depth: 8
# (2, 5, 3, 2, 5, 0)
# cost time 4.528393000000051
# terminated node: 0
# reached depth: 8
# (1, 5, 4, 0, 5, 2)
# cost time 3.8456820000001244
# terminated node: 0
# reached depth: 8
# (1, 3, 4, 6, 7, 1)
# cost time 4.818609999999808
# terminated node: 0
# reached depth: 8
# (2, 2, 4, 8, 4, 0)
# cost time 5.311251999999968
# terminated node: 0
# reached depth: 8
# (1, 2, 5, 7, 5, 0)
# cost time 4.930667000000085
# terminated node: 0
# reached depth: 8
# (2, 5, 4, 8, 5, 6)
# cost time 4.576856000000134
# terminated node: 0
# reached depth: 8
# (2, 5, 4, 2, 5, 3)
# cost time 4.229968999999983
# terminated node: 0
# reached depth: 8
# (1, 2, 2, 7, 7, 3)
# cost time 4.453679000000193
# terminated node: 0
# reached depth: 8
# (2, 5, 2, 6, 5, 5)
# cost time 3.945520000000215
# terminated node: 0
# reached depth: 8
# (1, 3, 4, 1, 7, 2)
# cost time 4.172178000000258
# terminated node: 0
# reached depth: 8
# (3, 5, 3, 0, 5, 7)
# cost time 4.020858999999746
# terminated node: 0
# reached depth: 8
# (2, 1, 4, 4, 7, 0)
# cost time 4.4387000000001535
# terminated node: 0
# reached depth: 8
# (1, 1, 1, 5, 6, 0)
# cost time 4.086892000000262
# terminated node: 0
# reached depth: 8
# (3, 3, 3, 5, 7, 7)
# cost time 4.568897000000106
# terminated node: 0
# reached depth: 8
# (1, 3, 2, 4, 7, 5)
# cost time 3.635707999999795
# terminated node: 0
# reached depth: 8
# (2, 2, 3, 3, 8, 7)
# cost time 3.7894639999999526
# terminated node: 0
# reached depth: 7
# (2, 3, 5, 8, 0, 0)
# cost time 3.629522000000179
# terminated node: 0
# reached depth: 6
# (5, 5, 5, 0, 0, 0)
# cost time 3.1383489999998346
# terminated node: 0
# reached depth: 8
# (2, 1, 4, 4, 6, 1)
# cost time 3.702132000000347
# terminated node: 0
# reached depth: 8
# (2, 4, 4, 6, 1, 0)
# cost time 3.5524179999997614
# terminated node: 0
# reached depth: 8
# (3, 4, 4, 7, 1, 5)
# cost time 2.752918000000136
# terminated node: 0
# reached depth: 8
# (2, 2, 5, 4, 5, 5)
# cost time 2.65468299999975
# terminated node: 17
# reached depth: 7
# (1, 5, 3, 5, 0, 0)
# cost time 2.5392109999997956
# terminated node: 19
# reached depth: 6
# (2, 5, 3, 5, 0, 4)
# cost time 1.4935660000001008
# terminated node: 29
# reached depth: 5
# (2, 2, 3, 6, 5, 7)
# cost time 1.454385000000002
# terminated node: 29
# reached depth: 4
# (2, 5, 2, 5, 0, 7)
# cost time 1.492949999999837
# terminated node: 32
# reached depth: 3
# (2, 5, 2, 3, 0, 5)
# cost time 0.8933590000001459
# terminated node: 45
# reached depth: 2
# (3, 5, 1, 7, 0, 9)
# cost time 0.7158709999998791
# terminated node: 48
# reached depth: 1
# (1, 5, 3, 3, 3, 7)
# cost time 0.43078700000023673
# terminated node: 49
# reached depth: 0
# (5, 5, 5, 0, 0, 10)
# [0.775, 35, 7.75]
# cost time 3.7870779999998376
# terminated node: 0
# reached depth: 8
# (2, 5, 3, 0, 5, 0)
# cost time 3.910903999999846
# terminated node: 0
# reached depth: 8
# (1, 5, 3, 2, 5, 0)
# cost time 3.9723860000003697
# terminated node: 0
# reached depth: 8
# (1, 5, 4, 9, 5, 0)
# cost time 4.723835000000236
# terminated node: 0
# reached depth: 8
# (1, 3, 2, 8, 7, 0)
# cost time 4.579099999999926
# terminated node: 0
# reached depth: 8
# (3, 5, 5, 5, 5, 0)
# cost time 4.040912999999819
# terminated node: 0
# reached depth: 8
# (1, 5, 3, 4, 5, 0)
# cost time 5.332992999999988
# terminated node: 0
# reached depth: 8
# (1, 4, 3, 8, 6, 2)
# cost time 4.9970909999997275
# terminated node: 0
# reached depth: 8
# (1, 2, 5, 9, 8, 4)
# cost time 5.028291000000081
# terminated node: 0
# reached depth: 8
# (1, 3, 5, 3, 7, 0)
# cost time 4.801894000000175
# terminated node: 0
# reached depth: 8
# (3, 5, 4, 0, 5, 3)
# cost time 5.0308460000001105
# terminated node: 0
# reached depth: 8
# (2, 5, 2, 7, 5, 5)
# cost time 4.300567999999657
# terminated node: 0
# reached depth: 8
# (2, 5, 3, 3, 5, 5)
# cost time 4.720537000000149
# terminated node: 0
# reached depth: 7
# (2, 5, 3, 5, 5, 5)
# ...
# reached depth: 7
# (2, 5, 5, 8, 0, 5)
# cost time 2.4765360000001237
# terminated node: 10
# reached depth: 7
# (3, 5, 3, 5, 0, 5)
# cost time 2.379653999999846
# terminated node: 12
# reached depth: 6
# (3, 5, 2, 5, 5, 8)
# cost time 1.631782999999814
# terminated node: 16
# reached depth: 5
# (5, 5, 4, 0, 0, 3)
# cost time 1.1782749999997577
# terminated node: 26
# reached depth: 4
# (4, 4, 1, 0, 6, 9)
# cost time 1.244438000000173
# terminated node: 30
# reached depth: 3
# (3, 5, 2, 5, 0, 8)
# cost time 0.7887869999999566
# terminated node: 46
# reached depth: 2
# (1, 5, 3, 0, 1, 7)
# cost time 0.686811999999918
# terminated node: 48
# reached depth: 1
# (4, 5, 2, 1, 0, 7)
# cost time 0.6202069999999367
# terminated node: 49
# reached depth: 0
# (5, 2, 3, 0, 0, 10)
# [0.838, 28, 8.379999999999999]
# cost time 4.686752999999953
# terminated node: 0
# reached depth: 8
# (2, 2, 2, 0, 8, 0)
# cost time 3.953450999999859
# terminated node: 0
# reached depth: 8
# (2, 5, 3, 0, 3, 0)
# cost time 4.4155470000000605
# terminated node: 0
# reached depth: 8
# (1, 4, 3, 9, 6, 0)
# cost time 4.3529419999999845
# terminated node: 0
# reached depth: 8
# (2, 4, 4, 7, 6, 0)
# cost time 4.191838000000189
# terminated node: 0
# reached depth: 8
# (1, 1, 2, 9, 5, 0)
# cost time 4.440883000000213
# terminated node: 0
# reached depth: 8
# (1, 3, 4, 6, 7, 0)
# cost time 4.1988759999999274
# terminated node: 0
# reached depth: 8
# (2, 3, 4, 8, 0, 0)
# cost time 4.8459100000000035
# terminated node: 0
# reached depth: 8
# (2, 1, 3, 8, 4, 0)
# cost time 4.532147999999779
# terminated node: 0
# reached depth: 8
# (3, 4, 2, 2, 6, 0)
# cost time 3.9190779999998995
# terminated node: 0
# reached depth: 8
# (4, 1, 4, 6, 3, 0)
# cost time 4.020208999999795
# terminated node: 0
# reached depth: 8
# (1, 2, 3, 5, 8, 0)
# cost time 3.9917860000000474
# terminated node: 0
# reached depth: 8
# (1, 2, 5, 6, 5, 0)
# cost time 3.9981269999998403
# terminated node: 0
# reached depth: 8
# (1, 5, 5, 9, 5, 3)
# cost time 4.031514000000243
# terminated node: 0
# reached depth: 8
# (2, 4, 2, 7, 6, 4)
# cost time 4.95566800000006
# terminated node: 0
# reached depth: 8
# (1, 5, 2, 5, 3, 0)
# cost time 4.363122000000203
# terminated node: 0
# reached depth: 7
# (2, 4, 2, 3, 6, 2)
# cost time 4.193480999999792
# terminated node: 0
# reached depth: 6
# (3, 3, 3, 0, 7, 3)
# cost time 4.909595000000081
# terminated node: 0
# reached depth: 8
# (4, 4, 4, 5, 6, 6)
# cost time 3.522002000000157
# terminated node: 1
# reached depth: 7
# (1, 5, 3, 4, 5, 4)
# cost time 3.526976999999988
# terminated node: 0
# reached depth: 6
# (4, 5, 5, 6, 0, 4)
# cost time 2.92024100000026
# terminated node: 3
# reached depth: 5
# (3, 5, 3, 2, 0, 0)
# cost time 2.0917030000000523
# terminated node: 7
# reached depth: 4
# (2, 5, 4, 0, 5, 6)
# cost time 1.881315000000086
# terminated node: 9
# reached depth: 3
# (3, 5, 3, 2, 5, 7)
# cost time 1.6562119999998686
# terminated node: 9
# reached depth: 2
# (4, 4, 4, 2, 0, 3)
# cost time 0.6526610000000801
# terminated node: 48
# reached depth: 1
# (2, 1, 5, 7, 5, 0)
# cost time 0.5822549999998046
# terminated node: 49
# reached depth: 0
# (5, 4, 5, 0, 0, 7)
# [0.659, 25, 6.59]
# cost time 4.585833000000093
# terminated node: 0
# reached depth: 8
# (3, 5, 3, 0, 5, 0)
# cost time 4.152023000000099
# terminated node: 0
# reached depth: 8
# (2, 2, 5, 8, 8, 0)
# cost time 3.9146120000000337
# terminated node: 0
# reached depth: 8
# (1, 1, 2, 9, 7, 0)
# cost time 4.532310000000052
# terminated node: 0
# reached depth: 8
# (2, 5, 2, 3, 5, 0)
# cost time 4.254396999999699
# terminated node: 0
# reached depth: 7
# (1, 5, 5, 5, 5, 0)
# cost time 4.223015000000032
# terminated node: 0
# reached depth: 7
# (2, 4, 4, 6, 6, 0)
# cost time 4.803882000000158
# terminated node: 0
# reached depth: 8
# (5, 5, 5, 5, 0, 0)
# cost time 4.519937000000027
# terminated node: 0
# reached depth: 7
# (3, 4, 3, 0, 6, 3)
# cost time 4.949388999999883
# terminated node: 0
# reached depth: 7
# (2, 5, 5, 3, 5, 2)
# cost time 4.2852319999997235
# terminated node: 0
# reached depth: 7
# (3, 5, 3, 0, 5, 6)
# cost time 4.419394999999895
# terminated node: 0
# reached depth: 7
# (2, 3, 4, 8, 5, 2)
# cost time 4.207431999999699
# terminated node: 0
# reached depth: 7
# (2, 4, 4, 6, 6, 4)
# cost time 4.577072000000044
# terminated node: 0
# reached depth: 6
# (5, 5, 4, 0, 0, 0)
# cost time 4.217595000000074
# terminated node: 0
# reached depth: 8
# (2, 5, 4, 8, 5, 6)
# cost time 3.840715999999702
# terminated node: 0
# reached depth: 8
# (1, 5, 4, 5, 5, 5)
# cost time 3.788094000000001
# terminated node: 0
# reached depth: 8
# (3, 5, 5, 7, 0, 5)
# cost time 2.3097869999996874
# terminated node: 0
# reached depth: 8
# (5, 5, 1, 0, 5, 9)
# cost time 1.815107999999782
# terminated node: 0
# reached depth: 8
# (2, 1, 3, 6, 5, 0)
# cost time 1.7459640000001855
# terminated node: 19
# reached depth: 7
# (2, 3, 2, 6, 7, 8)
# cost time 1.6312749999997322
# terminated node: 20
# reached depth: 6
# (2, 1, 3, 6, 5, 3)
# cost time 1.6272439999997914
# terminated node: 21
# reached depth: 5
# (1, 5, 1, 5, 5, 9)
# cost time 1.5891209999999774
# terminated node: 22
# reached depth: 4
# (3, 5, 5, 4, 0, 5)
# cost time 1.2383119999999508
# terminated node: 31
# reached depth: 3
# (4, 5, 2, 0, 0, 4)
# cost time 0.7585980000003474
# terminated node: 39
# reached depth: 2
# (3, 4, 4, 0, 0, 6)
# cost time 0.625177999999778
# terminated node: 48
# reached depth: 1
# (2, 1, 3, 6, 5, 6)
# cost time 0.40140000000019427
# terminated node: 49
# reached depth: 0
# (5, 5, 4, 0, 0, 10)
# [0.914, 25, 9.14]
# cost time 3.7673070000000735
# terminated node: 0
# reached depth: 8
# (2, 4, 3, 0, 6, 0)
# cost time 4.336052999999993
# terminated node: 0
# reached depth: 8
# (1, 3, 3, 9, 7, 0)
# cost time 5.058410999999978
# terminated node: 0
# reached depth: 8
# (4, 5, 4, 2, 5, 0)
# cost time 4.310167000000092
# terminated node: 0
# reached depth: 8
# (2, 4, 4, 7, 6, 0)
# cost time 4.764695000000302
# terminated node: 0
# reached depth: 8
# (2, 4, 3, 8, 6, 4)
# cost time 4.323669000000336
# terminated node: 0
# reached depth: 8
# (2, 1, 5, 8, 5, 0)
# cost time 4.407758999999714
# terminated node: 0
# reached depth: 8
# (2, 5, 4, 0, 5, 3)
# cost time 4.780479000000014
# terminated node: 0
# reached depth: 8
# (1, 5, 5, 6, 5, 0)
# cost time 4.705594000000019
# terminated node: 0
# reached depth: 8
# (3, 4, 3, 7, 6, 7)
# cost time 4.946302999999716
# terminated node: 0
# reached depth: 8
# (2, 4, 3, 2, 6, 4)
# cost time 4.086445999999796
# terminated node: 0
# reached depth: 8
# (1, 5, 3, 6, 5, 5)
# cost time 4.089046999999937
# terminated node: 0
# reached depth: 8
# (1, 5, 5, 5, 5, 4)
# cost time 4.7764139999999315
# terminated node: 0
# reached depth: 8
# (4, 5, 5, 6, 0, 0)
# cost time 3.7696169999999256
# terminated node: 0
# reached depth: 8
# (2, 4, 2, 0, 6, 7)
# cost time 4.271395000000211
# terminated node: 0
# reached depth: 8
# (2, 3, 3, 3, 7, 7)
# cost time 4.7376759999997375
# terminated node: 0
# reached depth: 8
# (2, 2, 4, 8, 4, 5)
# cost time 4.4604669999998805
# terminated node: 0
# reached depth: 8
# (5, 5, 1, 0, 0, 0)
# cost time 4.111112000000048
# terminated node: 0
# reached depth: 8
# (2, 3, 1, 5, 7, 9)
# cost time 3.9349569999999403
# terminated node: 0
# reached depth: 8
# (2, 3, 5, 8, 1, 5)
# cost time 4.10383899999988
# terminated node: 0
# reached depth: 8
# (3, 3, 3, 3, 2, 1)
# cost time 4.028053999999884
# terminated node: 0
# reached depth: 8
# (3, 5, 3, 0, 0, 1)
# cost time 3.015740000000278
# terminated node: 0
# reached depth: 8
# (2, 4, 4, 6, 1, 5)
# cost time 3.173327000000427
# terminated node: 0
# reached depth: 8
# (3, 5, 3, 3, 0, 4)
# cost time 2.158190000000104
# terminated node: 10
# reached depth: 8
# (4, 1, 5, 6, 0, 5)
# cost time 2.3772140000000945
# terminated node: 11
# reached depth: 8
# (1, 1, 3, 7, 5, 0)
# cost time 2.175112000000354
# terminated node: 18
# reached depth: 7
# (3, 4, 3, 2, 3, 7)
# cost time 0.695212999999967
# terminated node: 47
# reached depth: 2
# (1, 1, 3, 7, 5, 3)
# cost time 0.4774290000000292
# terminated node: 48
# reached depth: 1
# (2, 5, 3, 0, 1, 7)
# cost time 0.4115639999999985
# terminated node: 49
# reached depth: 0
# (2, 5, 3, 0, 0, 10)
# [0.796, 28, 7.960000000000001]
# cost time 4.166983999999957
# terminated node: 0
# reached depth: 8
# (1, 2, 2, 0, 8, 0)
# cost time 4.7787929999999506
# terminated node: 0
# reached depth: 8
# (3, 5, 4, 1, 5, 0)
# cost time 4.620558000000074
# terminated node: 0
# reached depth: 8
# (1, 3, 5, 9, 7, 0)
# cost time 4.744267000000036
# terminated node: 0
# reached depth: 8
# (2, 4, 5, 7, 6, 0)
# cost time 4.910876000000371
# terminated node: 0
# reached depth: 8
# (1, 2, 4, 9, 5, 0)
# cost time 4.632241999999678
# terminated node: 0
# reached depth: 8
# (3, 5, 5, 4, 5, 0)
# cost time 4.8599779999999555
# terminated node: 0
# reached depth: 8
# (2, 1, 1, 7, 5, 0)
# cost time 4.144460999999865
# terminated node: 0
# reached depth: 8
# (2, 5, 5, 8, 0, 0)
# cost time 4.450332999999773
# terminated node: 0
# reached depth: 8
# (2, 4, 2, 8, 6, 5)
# cost time 4.997064000000137
# terminated node: 0
# reached depth: 8
# (1, 1, 3, 8, 5, 1)
# cost time 4.7554339999996955
# terminated node: 0
# reached depth: 8
# (1, 4, 4, 0, 6, 2)
# cost time 5.261409000000185
# terminated node: 0
# reached depth: 7
# (3, 4, 5, 5, 0, 0)
# cost time 4.731877000000168
# terminated node: 0
# reached depth: 8
# (2, 4, 3, 6, 6, 5)
# cost time 5.018358999999691
# terminated node: 0
# reached depth: 8
# (4, 5, 3, 0, 0, 0)
# cost time 4.9130740000000515
# terminated node: 0
# reached depth: 8
# (2, 5, 5, 1, 5, 4)
# cost time 3.3068349999998645
# terminated node: 0
# reached depth: 8
# (2, 4, 3, 4, 6, 5)
# cost time 3.380185999999867
# terminated node: 0
# reached depth: 8
# (3, 1, 5, 5, 4, 0)
# cost time 4.095057999999881
# terminated node: 0
# reached depth: 8
# (1, 3, 2, 9, 7, 7)
# cost time 4.095938999999817
# terminated node: 0
# reached depth: 8
# (1, 2, 1, 9, 8, 9)
# cost time 3.5674549999998817
# terminated node: 0
# reached depth: 8
# (3, 3, 2, 6, 7, 8)
# cost time 4.744530999999824
# terminated node: 0
# reached depth: 8
# (1, 5, 2, 0, 5, 6)
# cost time 4.2738280000003215
# terminated node: 0
# reached depth: 8
# (3, 5, 1, 0, 5, 9)
# cost time 4.846143000000211
# terminated node: 0
# reached depth: 8
# (1, 4, 4, 3, 6, 4)
# cost time 3.964354000000185
# terminated node: 0
# reached depth: 8
# (2, 5, 5, 8, 1, 5)
# cost time 2.7450370000001385
# terminated node: 0
# reached depth: 8
# (1, 5, 3, 4, 0, 0)
# cost time 2.841613000000052
# terminated node: 0
# reached depth: 8
# (2, 4, 2, 4, 6, 8)
# cost time 2.6364410000001044
# terminated node: 0
# reached depth: 8
# (1, 5, 4, 7, 1, 5)
# cost time 2.0215029999999388
# terminated node: 32
# reached depth: 7
# (1, 5, 2, 3, 5, 8)
# cost time 2.1111269999996694
# terminated node: 26
# reached depth: 7
# (1, 2, 5, 6, 4, 5)
# cost time 1.500978000000032
# terminated node: 27
# reached depth: 6
# (1, 1, 3, 9, 6, 7)
# cost time 1.0829690000000483
# terminated node: 29
# reached depth: 5
# (1, 2, 4, 5, 4, 5)
# cost time 1.086685000000216
# terminated node: 29
# reached depth: 4
# (5, 5, 5, 0, 0, 3)
# cost time 0.6280430000001616
# terminated node: 44
# reached depth: 2
# (2, 4, 5, 5, 0, 5)
# cost time 0.4747349999997823
# terminated node: 48
# reached depth: 1
# (4, 4, 1, 0, 1, 8)
# cost time 0.4317729999997937
# terminated node: 49
# reached depth: 0
# (2, 5, 3, 0, 0, 9)
# [0.902, 34, 9.02]
# cost time 4.374875999999858
# terminated node: 0
# reached depth: 8
# (1, 5, 4, 0, 5, 0)
# cost time 4.644080000000031
# terminated node: 0
# reached depth: 8
# (2, 2, 2, 8, 8, 0)
# cost time 4.630979999999909
# terminated node: 0
# reached depth: 8
# (2, 3, 4, 8, 5, 0)
# cost time 4.02776300000005
# terminated node: 0
# reached depth: 8
# (2, 5, 3, 6, 5, 0)
# cost time 5.263781999999992
# terminated node: 0
# reached depth: 8
# (4, 5, 4, 1, 5, 0)
# cost time 3.438904999999977
# terminated node: 0
# reached depth: 8
# (1, 4, 1, 5, 6, 0)
# cost time 3.2632439999997587
# terminated node: 0
# reached depth: 8
# (1, 4, 3, 5, 6, 1)
# cost time 3.772562000000107
# terminated node: 0
# reached depth: 8
# (2, 2, 5, 8, 8, 2)
# cost time 3.645911000000069
# terminated node: 0
# reached depth: 8
# (1, 4, 4, 7, 6, 3)
# cost time 4.4259900000001835
# terminated node: 0
# reached depth: 8
# (2, 3, 2, 8, 5, 4)
# cost time 4.2364220000004025
# terminated node: 0
# reached depth: 8
# (1, 2, 2, 6, 8, 3)
# cost time 4.266622999999981
# terminated node: 0
# reached depth: 8
# (2, 1, 4, 8, 4, 0)
# cost time 4.227894000000106
# terminated node: 0
# reached depth: 8
# (3, 4, 4, 7, 0, 0)
# cost time 4.796763999999712
# terminated node: 0
# reached depth: 8
# (3, 5, 4, 0, 5, 4)
# cost time 4.789788000000044
# terminated node: 0
# reached depth: 8
# (2, 5, 3, 3, 5, 4)
# cost time 4.001052999999956
# terminated node: 0
# reached depth: 8
# (2, 2, 3, 8, 8, 7)
# cost time 4.9415539999999964
# terminated node: 0
# reached depth: 8
# (1, 5, 5, 5, 5, 4)
# cost time 4.014115999999831
# terminated node: 0
# reached depth: 8
# (1, 4, 2, 9, 4, 6)
# cost time 4.327608000000055
# terminated node: 0
# reached depth: 8
# (3, 5, 3, 4, 0, 0)
# cost time 4.656233000000157
# terminated node: 0
# reached depth: 8
# (4, 5, 2, 0, 5, 8)
# cost time 4.730849000000035
# terminated node: 0
# reached depth: 8
# (4, 5, 3, 0, 0, 0)
# cost time 3.8962390000001506
# terminated node: 0
# reached depth: 8
# (2, 5, 3, 7, 3, 7)
# cost time 3.4474559999998746
# terminated node: 0
# reached depth: 8
# (2, 2, 2, 6, 8, 7)
# cost time 3.165563999999904
# terminated node: 0
# reached depth: 8
# (1, 5, 1, 6, 5, 9)
# cost time 3.135827000000063
# terminated node: 12
# reached depth: 7
# (4, 5, 3, 0, 0, 3)
# cost time 2.810461999999916
# terminated node: 14
# reached depth: 6
# (2, 5, 2, 5, 0, 3)
# cost time 2.7830650000000787
# terminated node: 16
# reached depth: 5
# (2, 3, 5, 8, 0, 4)
# cost time 1.937782999999854
# terminated node: 25
# reached depth: 4
# (2, 3, 4, 5, 2, 5)
# cost time 1.0855320000000575
# terminated node: 41
# reached depth: 3
# (1, 3, 3, 4, 7, 7)
# cost time 0.9412529999999606
# terminated node: 42
# reached depth: 2
# (1, 4, 4, 4, 1, 3)
# cost time 0.5951320000003761
# terminated node: 48
# reached depth: 1
# (1, 4, 4, 0, 1, 6)
# cost time 0.42117599999983213
# terminated node: 49
# reached depth: 0
# (5, 5, 5, 0, 0, 10)
# [0.784, 31, 7.84]
# cost time 4.1432159999999385
# terminated node: 0
# reached depth: 8
# (1, 3, 2, 0, 7, 0)
# cost time 4.789856999999756
# terminated node: 0
# reached depth: 8
# (2, 5, 4, 1, 5, 0)
# cost time 4.856685000000198
# terminated node: 0
# reached depth: 8
# (1, 4, 1, 9, 6, 0)
# cost time 5.232492000000093
# terminated node: 0
# reached depth: 8
# (2, 5, 5, 7, 5, 0)
# cost time 4.918388999999934
# terminated node: 0
# reached depth: 8
# (3, 1, 4, 4, 9, 0)
# cost time 5.422048000000359
# terminated node: 0
# reached depth: 8
# (2, 5, 3, 5, 4, 0)
# cost time 5.17033100000026
# terminated node: 0
# reached depth: 7
# (3, 4, 4, 7, 0, 0)
# cost time 5.347078999999667
# terminated node: 0
# reached depth: 7
# (3, 4, 3, 4, 0, 0)
# cost time 4.573484999999891
# terminated node: 0
# reached depth: 8
# (1, 2, 1, 9, 8, 1)
# cost time 4.891403999999966
# terminated node: 0
# reached depth: 8
# (4, 5, 5, 0, 0, 0)
# cost time 5.253498000000036
# terminated node: 0
# reached depth: 8
# (3, 3, 3, 7, 7, 5)
# cost time 5.406921000000239
# terminated node: 0
# reached depth: 8
# (2, 4, 3, 3, 5, 0)
# cost time 5.384739000000081
# terminated node: 0
# reached depth: 8
# (1, 5, 3, 6, 4, 3)
# cost time 5.512928000000102
# terminated node: 0
# reached depth: 8
# (3, 4, 4, 0, 6, 4)
# cost time 5.414912000000186
# terminated node: 0
# reached depth: 8
# (3, 1, 2, 7, 4, 0)
# cost time 4.724121000000196
# terminated node: 0
# reached depth: 8
# (2, 4, 4, 4, 6, 4)
# cost time 4.91847000000007
# terminated node: 0
# reached depth: 8
# (1, 4, 4, 3, 6, 3)
# cost time 4.954123999999865
# terminated node: 0
# reached depth: 8
# (1, 3, 5, 9, 4, 2)
# cost time 5.330329999999776
# terminated node: 0
# reached depth: 8
# (2, 2, 3, 8, 5, 7)
# cost time 4.812653999999839
# terminated node: 0
# reached depth: 8
# (1, 5, 4, 8, 0, 4)
# cost time 4.444495999999617
# terminated node: 0
# reached depth: 8
# (3, 5, 2, 5, 5, 8)
# cost time 4.217552999999953
# terminated node: 0
# reached depth: 8
# (1, 3, 3, 9, 1, 4)
# cost time 4.5612019999998665
# terminated node: 0
# reached depth: 8
# (3, 5, 2, 7, 0, 8)
# cost time 3.8140089999997144
# terminated node: 0
# reached depth: 8
# (1, 2, 2, 9, 7, 8)
# cost time 3.096921999999722
# terminated node: 0
# reached depth: 8
# (2, 5, 1, 3, 5, 8)
# cost time 3.351760000000013
# terminated node: 4
# reached depth: 8
# (1, 2, 1, 8, 8, 8)
# cost time 3.295325000000048
# terminated node: 4
# reached depth: 6
# (3, 4, 2, 0, 6, 8)
# cost time 2.870965999999953
# terminated node: 6
# reached depth: 5
# (3, 4, 5, 4, 0, 3)
# cost time 1.3650979999997617
# terminated node: 30
# reached depth: 4
# (3, 4, 2, 4, 0, 8)
# cost time 1.2439269999999851
# terminated node: 42
# reached depth: 3
# (2, 2, 4, 2, 3, 5)
# cost time 0.7529880000001867
# terminated node: 47
# reached depth: 2
# (2, 3, 1, 3, 7, 9)
# cost time 0.7606850000001941
# terminated node: 48
# reached depth: 1
# (1, 5, 5, 0, 1, 5)
# cost time 0.533125000000382
# terminated node: 49
# reached depth: 0
# (5, 2, 5, 0, 0, 10)
# [0.783, 32, 7.83]

# %%
#3000 #90个容器的空间利用率

# %%
print(results)
mean = np.array(results).mean(axis=0)
print(mean)
# Out:
# [[0.824, 30, 8.24], [0.823, 34, 8.23], [0.802, 34, 8.02], [0.749, 36, 7.49], [0.827, 38, 8.27], [0.791, 30, 7.91], [0.767, 30, 7.67], [0.755, 29, 7.55], [0.767, 31, 7.67], [0.832, 36, 8.32], [0.826, 34, 8.26], [0.785, 26, 7.8500000000000005], [0.792, 28, 7.92], [0.867, 26, 8.67], [0.802, 30, 8.02], [0.805, 32, 8.05], [0.775, 35, 7.75], [0.826, 31, 8.26], [0.804, 28, 8.040000000000001], [0.813, 37, 8.129999999999999], [0.705, 23, 7.05], [0.822, 37, 8.219999999999999], [0.688, 32, 6.879999999999999], [0.838, 28, 8.379999999999999], [0.659, 25, 6.59], [0.914, 25, 9.14], [0.796, 28, 7.960000000000001], [0.902, 34, 9.02], [0.784, 31, 7.84], [0.783, 32, 7.83]]
# [ 0.79743333 31.          7.97433333]
