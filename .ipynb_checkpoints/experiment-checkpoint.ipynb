# %%
import gym
import copy
import numpy as np
import time
import sys 
import torch
sys.path.append("MCTS") 
from monteCarlo import MCTree
import tools
from tools import get_args, registration_envs
from model import DRL_GAT
from network import nmodel
# Out:
# pretrained_models/PCT_setting1.pt
# Loading pre-train upper model pretrained_models/PCT_setting1.pt
# Pre-train model loaded! pretrained_models/PCT_setting1.pt

# %%
registration_envs()
args = get_args()
env = gym.make(args.id,
               setting = args.setting,
               item_set = args.item_size_set,
               container_size=args.container_size,
               internal_node_holder = args.internal_node_holder,
               leaf_node_holder = args.leaf_node_holder,
               LNES = args.lnes,
               shuffle=args.shuffle,
               sample_from_distribution=args.sample_from_distribution,
               sample_left_bound=args.sample_left_bound,
               sample_right_bound=args.sample_right_bound
               )
if args.no_cuda:
        device = torch.device('cpu')
else:
    device = torch.device('cuda', args.device)
    torch.cuda.set_device(args.device)
# Out:
# [(1, 1, 1), (1, 1, 2), (1, 1, 3), (1, 1, 4), (1, 1, 5), (1, 2, 1), (1, 2, 2), (1, 2, 3), (1, 2, 4), (1, 2, 5), (1, 3, 1), (1, 3, 2), (1, 3, 3), (1, 3, 4), (1, 3, 5), (1, 4, 1), (1, 4, 2), (1, 4, 3), (1, 4, 4), (1, 4, 5), (1, 5, 1), (1, 5, 2), (1, 5, 3), (1, 5, 4), (1, 5, 5), (2, 1, 1), (2, 1, 2), (2, 1, 3), (2, 1, 4), (2, 1, 5), (2, 2, 1), (2, 2, 2), (2, 2, 3), (2, 2, 4), (2, 2, 5), (2, 3, 1), (2, 3, 2), (2, 3, 3), (2, 3, 4), (2, 3, 5), (2, 4, 1), (2, 4, 2), (2, 4, 3), (2, 4, 4), (2, 4, 5), (2, 5, 1), (2, 5, 2), (2, 5, 3), (2, 5, 4), (2, 5, 5), (3, 1, 1), (3, 1, 2), (3, 1, 3), (3, 1, 4), (3, 1, 5), (3, 2, 1), (3, 2, 2), (3, 2, 3), (3, 2, 4), (3, 2, 5), (3, 3, 1), (3, 3, 2), (3, 3, 3), (3, 3, 4), (3, 3, 5), (3, 4, 1), (3, 4, 2), (3, 4, 3), (3, 4, 4), (3, 4, 5), (3, 5, 1), (3, 5, 2), (3, 5, 3), (3, 5, 4), (3, 5, 5), (4, 1, 1), (4, 1, 2), (4, 1, 3), (4, 1, 4), (4, 1, 5), (4, 2, 1), (4, 2, 2), (4, 2, 3), (4, 2, 4), (4, 2, 5), (4, 3, 1), (4, 3, 2), (4, 3, 3), (4, 3, 4), (4, 3, 5), (4, 4, 1), (4, 4, 2), (4, 4, 3), (4, 4, 4), (4, 4, 5), (4, 5, 1), (4, 5, 2), (4, 5, 3), (4, 5, 4), (4, 5, 5), (5, 1, 1), (5, 1, 2), (5, 1, 3), (5, 1, 4), (5, 1, 5), (5, 2, 1), (5, 2, 2), (5, 2, 3), (5, 2, 4), (5, 2, 5), (5, 3, 1), (5, 3, 2), (5, 3, 3), (5, 3, 4), (5, 3, 5), (5, 4, 1), (5, 4, 2), (5, 4, 3), (5, 4, 4), (5, 4, 5), (5, 5, 1), (5, 5, 2), (5, 5, 3), (5, 5, 4), (5, 5, 5)]
# /root/anaconda3/envs/intelcup/lib/python3.7/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))

# %%
def testMCTS(box_size_list, env, obser, simulation_times, search_depth, rollout_length):
    sim_env = copy.deepcopy(env)
    size_idx = len(box_size_list)
    action_list = []
    box_size_distribution = dict()
    box_num = 0
    sum_reward = 0
    # print("length: ", size_idx)
    
    mctree = MCTree(sim_env, obser, box_size_list, search_depth=search_depth, rollout_length=rollout_length)
    while True:
        # show some information
        # print(box_size_list[:10])
        # print(sim_env.space.plain)
        # MCTS simulation
        pl = mctree.get_policy(simulation_times, zeta=1e-5)
        action = mctree.sample_action(pl)
        
        assert sim_env.next_box == box_size_list[0]
        obser, r, done, dt = sim_env.step(action)
        sum_reward += r
        if done:
            dt['reward'] = sum_reward
            # print('---------------------')
            # print(dt)
            # print('---------------------')
            # print(action_list)
            # print('---------------------')
            # print(sim_env.space.plain)
            # print('---------------------')
            for (key, value) in box_size_distribution.items():
                box_size_distribution[key] = value / box_num
            # print(box_size_distribution)
            # print('---------------------')
            return [dt['ratio'], dt['counter'], dt['reward']]

        # fetch new box    
        assert size_idx <= len(env.box_creator.box_list)
        next_box = copy.deepcopy(env.box_creator.box_list[size_idx])
        size_idx += 1
        # update dis
        # tribution
        box_num += 1
        new_put_box = tuple(box_size_list[0])
        if new_put_box not in box_size_distribution:
            box_size_distribution[new_put_box] = 0
        box_size_distribution[new_put_box] += 1
        # update action
        action_list.append(action)
        # to next node
        mctree.succeed(action, next_box, obser)
def testPCT(env, obser, factor = 1):
    eval_envs = copy.deepcopy(env)
    PCT_policy = nmodel.PCT_policy
    obs = copy.deepcopy(obser)
    obs = torch.FloatTensor(obs).to(device).unsqueeze(dim=0)
    all_nodes, leaf_nodes = tools.get_leaf_nodes_with_factor(obs, args.num_processes,
                                                             args.internal_node_holder, args.leaf_node_holder)
    batchX = torch.arange(args.num_processes)
    episode_ratio = []
    episode_length = []
    
    while True:
        with torch.no_grad():
            selectedlogProb, selectedIdx, policy_dist_entropy, value = PCT_policy(all_nodes, True, normFactor = factor)
        action_mask = eval_envs.get_possible_position()
        
        selected_leaf_node = leaf_nodes[batchX, selectedIdx.squeeze()]
        items = eval_envs.packed
        obs, reward, done, infos = eval_envs.step(selected_leaf_node.cpu().numpy()[0][0:6])

        if done:
            return [infos['ratio'], infos['counter'], infos['reward']]

        obs = torch.FloatTensor(obs).to(device).unsqueeze(dim=0)
        all_nodes, leaf_nodes = tools.get_leaf_nodes_with_factor(obs, args.num_processes,
                                                                 args.internal_node_holder, args.leaf_node_holder)
        all_nodes, leaf_nodes = all_nodes.to(device), leaf_nodes.to(device)

    
def compare_test(env, args_list, times=5):
    result = {'MCTS':[],'PCT':[]}
    print("Case number: %d"%times)
    for i in range(times):
        print('Case %d' % (i+1))
        obser = env.reset()
        next_box_size_list = env.box_creator.preview(1000)
         
        print('//////////////////////////////////////////////////')
        start = time.time()
        ratio, counter, reward = testMCTS(next_box_size_list[:4], env, obser, *args_list)
        end = time.time()
        result['MCTS'].append([ratio, counter, reward, end-start])   
        print('mcts done')
        
        start = time.time()
        ratio, counter, reward = testPCT(env,obser)
        end = time.time()
        result['PCT'].append([ratio, counter, reward, end-start])   
        print('pct done')
            
        print('//////////////////////////////////////////////////')
    for (key, value) in result.items():
        result[key] = np.array(value)
    return result

# %%
args_list = [100, None, -1]
# args_list.append([1,0,0])
# args_list.append([400, 1, -1])
# args_list.append([400, None, -1])
# args_list.append([100, None, -1])
result = compare_test(env, args_list, 50)
# Out:
# Case number: 50
# Case 1
# //////////////////////////////////////////////////
# err
# err
# err
# err
# err
# err
# cost time 2.2803389999999695
# terminated node: 0
# reached depth: 3
# reused simulation times: 99
# children node number: 33
# err
# err
# cost time 2.1440190000000143
# terminated node: 0
# reached depth: 3
# reused simulation times: 197
# children node number: 50
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# cost time 2.9328629999999976
# terminated node: 0
# reached depth: 3
# reused simulation times: 168
# children node number: 50
# err
# err
# err
# err
# err
# err
# err
# err
# cost time 2.5770580000000223
# terminated node: 0
# reached depth: 3
# reused simulation times: 245
# children node number: 50
# cost time 2.3576610000000073
# terminated node: 0
# reached depth: 3
# reused simulation times: 233
# children node number: 50
# cost time 2.3988749999999754
# terminated node: 0
# reached depth: 3
# reused simulation times: 271
# children node number: 50
# err
# err
# err
# err
# err
# err
# err
# err
# cost time 2.6848850000000084
# terminated node: 0
# reached depth: 3
# reused simulation times: 239
# children node number: 50
# cost time 2.43133899999998
# terminated node: 0
# reached depth: 3
# reused simulation times: 237
# children node number: 50
# err
# err
# err
# err
# err
# err
# err
# err
# cost time 3.1735109999999622
# terminated node: 0
# reached depth: 3
# reused simulation times: 264
# children node number: 50
# err
# err
# err
# cost time 2.5602250000000595
# terminated node: 0
# reached depth: 3
# reused simulation times: 294
# children node number: 45
# cost time 3.0567499999999654
# terminated node: 0
# reached depth: 3
# reused simulation times: 208
# children node number: 50
# cost time 2.786968999999999
# terminated node: 0
# reached depth: 3
# reused simulation times: 297
# children node number: 50
# cost time 2.8763890000000174
# terminated node: 0
# reached depth: 3
# reused simulation times: 274
# children node number: 50
# cost time 2.890647999999942
# terminated node: 0
# reached depth: 3
# reused simulation times: 300
# children node number: 50
# err
# cost time 3.1236940000000004
# terminated node: 0
# reached depth: 3
# reused simulation times: 294
# children node number: 50
# cost time 2.6543000000000347
# terminated node: 0
# reached depth: 3
# reused simulation times: 299
# children node number: 50
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# cost time 3.1338180000000193
# terminated node: 0
# reached depth: 3
# reused simulation times: 242
# children node number: 50
# err
# err
# err
# cost time 2.3527859999999237
# terminated node: 0
# reached depth: 3
# reused simulation times: 251
# children node number: 9
# err
# err
# err
# err
# cost time 1.8340799999999717
# terminated node: 0
# reached depth: 3
# reused simulation times: 178
# children node number: 50
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# cost time 1.9306639999999788
# terminated node: 5
# reached depth: 3
# reused simulation times: 207
# children node number: 4
# err
# cost time 2.2126879999999574
# terminated node: 2
# reached depth: 3
# reused simulation times: 236
# children node number: 4
# cost time 1.9340190000000348
# terminated node: 0
# reached depth: 3
# reused simulation times: 262
# children node number: 50
# cost time 2.147032000000081
# terminated node: 63
# reached depth: 2
# reused simulation times: 204
# children node number: 19
# cost time 1.1894449999999779
# terminated node: 85
# reached depth: 1
# reused simulation times: 248
# children node number: 1
# cost time 0.6549759999999196
# terminated node: 100
# reached depth: 0
# mcts done
# pct done
# //////////////////////////////////////////////////
# Case 2
# //////////////////////////////////////////////////
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# cost time 1.8213660000000118
# terminated node: 0
# reached depth: 3
# reused simulation times: 99
# children node number: 33
# err
# err
# cost time 2.8839159999999993
# terminated node: 0
# reached depth: 3
# reused simulation times: 196
# children node number: 50
# err
# err
# err
# err
# cost time 2.660978
# terminated node: 0
# reached depth: 3
# reused simulation times: 293
# children node number: 50
# cost time 2.7786029999999755
# terminated node: 0
# reached depth: 3
# reused simulation times: 199
# children node number: 50
# cost time 2.2279539999999542
# terminated node: 0
# reached depth: 3
# reused simulation times: 288
# children node number: 50
# err
# err
# err
# err
# err
# err
# cost time 2.4540430000000697
# terminated node: 0
# reached depth: 3
# reused simulation times: 287
# children node number: 50
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# cost time 3.1657979999999952
# terminated node: 0
# reached depth: 3
# reused simulation times: 256
# children node number: 50
# err
# err
# err
# err
# err
# err
# err
# err
# cost time 2.8113989999999376
# terminated node: 0
# reached depth: 3
# reused simulation times: 250
# children node number: 50
# cost time 2.6518069999999625
# terminated node: 0
# reached depth: 3
# reused simulation times: 251
# children node number: 50
# cost time 2.4354569999999285
# terminated node: 0
# reached depth: 3
# reused simulation times: 286
# children node number: 50
# cost time 2.4351350000000593
# terminated node: 0
# reached depth: 3
# reused simulation times: 289
# children node number: 50
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# cost time 3.1839939999999842
# terminated node: 0
# reached depth: 3
# reused simulation times: 292
# children node number: 50
# err
# err
# err
# err
# err
# err
# cost time 2.868822000000023
# terminated node: 0
# reached depth: 3
# reused simulation times: 267
# children node number: 29
# err
# cost time 2.0108279999999468
# terminated node: 0
# reached depth: 3
# reused simulation times: 217
# children node number: 26
# cost time 2.0021130000000085
# terminated node: 0
# reached depth: 3
# reused simulation times: 240
# children node number: 9
# cost time 2.1627079999999523
# terminated node: 0
# reached depth: 3
# reused simulation times: 293
# children node number: 50
# err
# err
# cost time 2.1473929999999655
# terminated node: 0
# reached depth: 3
# reused simulation times: 300
# children node number: 50
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# cost time 2.83605799999998
# terminated node: 0
# reached depth: 3
# reused simulation times: 286
# children node number: 14
# cost time 2.1085110000000213
# terminated node: 0
# reached depth: 3
# reused simulation times: 276
# children node number: 35
# cost time 2.4545010000000502
# terminated node: 47
# reached depth: 2
# reused simulation times: 213
# children node number: 50
# cost time 1.6905189999999948
# terminated node: 69
# reached depth: 1
# reused simulation times: 216
# children node number: 1
# cost time 0.6230389999999488
# terminated node: 100
# reached depth: 0
# mcts done
# pct done
# //////////////////////////////////////////////////
# Case 3
# //////////////////////////////////////////////////
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# cost time 1.9657789999999977
# terminated node: 0
# reached depth: 3
# reused simulation times: 99
# children node number: 50
# cost time 2.0228100000000495
# terminated node: 0
# reached depth: 3
# reused simulation times: 191
# children node number: 50
# cost time 2.5412559999999758
# terminated node: 0
# reached depth: 3
# reused simulation times: 206
# children node number: 50
# cost time 2.386598000000049
# terminated node: 0
# reached depth: 3
# reused simulation times: 300
# children node number: 50
# err
# cost time 2.462163999999916
# terminated node: 0
# reached depth: 3
# reused simulation times: 276
# children node number: 50
# cost time 2.2836429999999837
# terminated node: 0
# reached depth: 3
# reused simulation times: 298
# children node number: 50
# cost time 2.198417000000063
# terminated node: 0
# reached depth: 3
# reused simulation times: 290
# children node number: 50
# cost time 2.336750000000052
# terminated node: 0
# reached depth: 3
# reused simulation times: 300
# children node number: 50
# cost time 2.4824439999999868
# terminated node: 0
# reached depth: 3
# reused simulation times: 292
# children node number: 50
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# cost time 2.717805999999996
# terminated node: 0
# reached depth: 3
# reused simulation times: 300
# children node number: 50
# cost time 2.6989360000000033
# terminated node: 0
# reached depth: 3
# reused simulation times: 278
# children node number: 49
# err
# err
# err
# cost time 2.778942000000029
# terminated node: 0
# reached depth: 3
# reused simulation times: 286
# children node number: 50
# cost time 2.7146960000000036
# terminated node: 0
# reached depth: 3
# reused simulation times: 276
# children node number: 50
# cost time 2.761769000000072
# terminated node: 0
# reached depth: 3
# reused simulation times: 268
# children node number: 50
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# cost time 3.5939799999999877
# terminated node: 0
# reached depth: 3
# reused simulation times: 295
# children node number: 50
# err
# err
# err
# err
# err
# err
# err
# err
# cost time 3.004583000000025
# terminated node: 0
# reached depth: 3
# reused simulation times: 249
# children node number: 50
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# cost time 3.612577999999985
# terminated node: 0
# reached depth: 3
# reused simulation times: 152
# children node number: 14
# err
# err
# cost time 2.790582000000086
# terminated node: 0
# reached depth: 3
# reused simulation times: 246
# children node number: 50
# cost time 2.832261000000017
# terminated node: 0
# reached depth: 3
# reused simulation times: 183
# children node number: 50
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# cost time 3.3735319999999547
# terminated node: 0
# reached depth: 3
# reused simulation times: 272
# children node number: 50
# err
# cost time 2.4294869999999946
# terminated node: 0
# reached depth: 3
# reused simulation times: 261
# children node number: 50
# err
# err
# cost time 2.711930999999936
# terminated node: 0
# reached depth: 3
# reused simulation times: 212
# children node number: 7
# err
# err
# err
# cost time 2.1418350000000146
# terminated node: 0
# reached depth: 3
# reused simulation times: 297
# children node number: 50
# cost time 2.166755999999964
# terminated node: 0
# reached depth: 3
# reused simulation times: 195
# children node number: 11
# err
# err
# err
# err
# err
# err
# cost time 2.189901000000077
# terminated node: 0
# reached depth: 3
# reused simulation times: 294
# children node number: 35
# err
# err
# cost time 2.034622000000013
# terminated node: 0
# reached depth: 3
# reused simulation times: 295
# children node number: 50
# cost time 2.296564999999987
# terminated node: 0
# reached depth: 3
# reused simulation times: 272
# children node number: 8
# err
# err
# err
# err
# err
# err
# err
# cost time 2.37328100000002
# terminated node: 0
# reached depth: 3
# reused simulation times: 289
# children node number: 39
# cost time 2.180623999999966
# terminated node: 58
# reached depth: 2
# reused simulation times: 154
# children node number: 25
# cost time 1.0210800000000972
# terminated node: 100
# reached depth: 1
# reused simulation times: 96
# children node number: 1
# cost time 0.6748139999999694
# terminated node: 100
# reached depth: 0
# mcts done
# pct done
# //////////////////////////////////////////////////
# Case 4
# //////////////////////////////////////////////////
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# cost time 1.991019999999935
# terminated node: 0
# reached depth: 3
# reused simulation times: 99
# children node number: 33
# cost time 2.076473000000078
# terminated node: 0
# reached depth: 3
# reused simulation times: 197
# children node number: 50
# cost time 2.213231999999948
# terminated node: 0
# reached depth: 3
# reused simulation times: 250
# children node number: 50
# cost time 2.277595999999903
# terminated node: 0
# reached depth: 3
# reused simulation times: 300
# children node number: 50
# cost time 2.2743319999999585
# terminated node: 0
# reached depth: 3
# reused simulation times: 300
# children node number: 50
# cost time 2.084615000000099
# terminated node: 0
# reached depth: 3
# reused simulation times: 300
# children node number: 50
# cost time 2.1998210000000427
# terminated node: 0
# reached depth: 3
# reused simulation times: 288
# children node number: 50
# cost time 2.4607770000000073
# terminated node: 0
# reached depth: 3
# reused simulation times: 190
# children node number: 50
# cost time 2.414444000000003
# terminated node: 0
# reached depth: 3
# reused simulation times: 288
# children node number: 50
# err
# err
# err
# err
# err
# err
# err
# err
# cost time 2.5677220000000034
# terminated node: 0
# reached depth: 3
# reused simulation times: 285
# children node number: 50
# err
# err
# err
# err
# err
# cost time 2.698951999999963
# terminated node: 0
# reached depth: 3
# reused simulation times: 93
# children node number: 50
# err
# cost time 2.4933990000000676
# terminated node: 0
# reached depth: 3
# reused simulation times: 104
# children node number: 50
# cost time 2.270167000000015
# terminated node: 0
# reached depth: 3
# reused simulation times: 200
# children node number: 50
# cost time 2.473732000000041
# terminated node: 0
# reached depth: 3
# reused simulation times: 299
# children node number: 50
# err
# err
# err
# err
# err
# cost time 2.6951279999999542
# terminated node: 0
# reached depth: 3
# reused simulation times: 283
# children node number: 44
# err
# err
# err
# err
# err
# err
# cost time 2.8024709999999686
# terminated node: 0
# reached depth: 3
# reused simulation times: 294
# children node number: 50
# err
# cost time 2.6985070000000633
# terminated node: 0
# reached depth: 3
# reused simulation times: 248
# children node number: 50
# err
# err
# err
# cost time 2.9427369999999655
# terminated node: 0
# reached depth: 3
# reused simulation times: 286
# children node number: 50
# err
# cost time 2.643395999999939
# terminated node: 0
# reached depth: 3
# reused simulation times: 176
# children node number: 50
# err
# err
# err
# err
# cost time 3.444458999999938
# terminated node: 0
# reached depth: 3
# reused simulation times: 168
# children node number: 50
# err
# cost time 2.6162350000000743
# terminated node: 0
# reached depth: 3
# reused simulation times: 261
# children node number: 50
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# cost time 3.2027100000000246
# terminated node: 0
# reached depth: 3
# reused simulation times: 216
# children node number: 50
# err
# err
# cost time 2.077573999999913
# terminated node: 0
# reached depth: 3
# reused simulation times: 191
# children node number: 10
# err
# err
# err
# err
# cost time 2.1964929999999185
# terminated node: 0
# reached depth: 3
# reused simulation times: 234
# children node number: 50
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# cost time 2.2913240000000314
# terminated node: 0
# reached depth: 3
# reused simulation times: 291
# children node number: 30
# cost time 1.5719309999999496
# terminated node: 0
# reached depth: 3
# reused simulation times: 267
# children node number: 15
# err
# err
# err
# err
# cost time 1.6489809999999352
# terminated node: 72
# reached depth: 2
# reused simulation times: 239
# children node number: 18
# cost time 1.002211999999986
# terminated node: 97
# reached depth: 1
# reused simulation times: 269
# children node number: 1
# cost time 0.6627070000000685
# terminated node: 100
# reached depth: 0
# mcts done
# pct done
# //////////////////////////////////////////////////
# Case 5
# //////////////////////////////////////////////////
# err
# err
# err
# cost time 1.7393089999999347
# terminated node: 0
# reached depth: 3
# reused simulation times: 99
# children node number: 25
# err
# cost time 1.7907209999999623
# terminated node: 0
# reached depth: 3
# reused simulation times: 197
# children node number: 50
# cost time 1.8058089999999538
# terminated node: 0
# reached depth: 3
# reused simulation times: 218
# children node number: 39
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# cost time 2.0487319999999727
# terminated node: 0
# reached depth: 3
# reused simulation times: 277
# children node number: 45
# cost time 2.1251199999999244
# terminated node: 0
# reached depth: 3
# reused simulation times: 294
# children node number: 40
# cost time 2.0690759999999955
# terminated node: 0
# reached depth: 3
# reused simulation times: 281
# children node number: 50
# err
# err
# err
# err
# cost time 2.2721430000000282
# terminated node: 0
# reached depth: 3
# reused simulation times: 290
# children node number: 50
# cost time 2.089743999999996
# terminated node: 0
# reached depth: 3
# reused simulation times: 296
# children node number: 24
# cost time 2.219923999999992
# terminated node: 0
# reached depth: 3
# reused simulation times: 276
# children node number: 50
# cost time 2.1937020000000302
# terminated node: 0
# reached depth: 3
# reused simulation times: 300
# children node number: 49
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# cost time 3.0040109999999913
# terminated node: 0
# reached depth: 3
# reused simulation times: 300
# children node number: 50
# err
# err
# err
# cost time 2.320944000000054
# terminated node: 0
# reached depth: 3
# reused simulation times: 286
# children node number: 38
# cost time 2.216111999999953
# terminated node: 0
# reached depth: 3
# reused simulation times: 233
# children node number: 50
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# cost time 3.1696909999999434
# terminated node: 0
# reached depth: 3
# reused simulation times: 221
# children node number: 25
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# cost time 2.4729300000000194
# terminated node: 0
# reached depth: 3
# reused simulation times: 227
# children node number: 50
# cost time 1.8829359999999724
# terminated node: 0
# reached depth: 3
# reused simulation times: 146
# children node number: 49
# cost time 1.1696620000000166
# terminated node: 98
# reached depth: 2
# reused simulation times: 244
# children node number: 2
# cost time 0.7466480000000502
# terminated node: 100
# reached depth: 1
# reused simulation times: 298
# children node number: 1
# cost time 0.6095379999999295
# terminated node: 100
# reached depth: 0
# mcts done
# pct done
# //////////////////////////////////////////////////
# Case 6
# //////////////////////////////////////////////////
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# cost time 2.103484999999978
# terminated node: 0
# reached depth: 3
# reused simulation times: 99
# children node number: 33
# err
# err
# err
# err
# err
# cost time 2.1957140000000663
# terminated node: 0
# reached depth: 3
# reused simulation times: 132
# children node number: 50
# err
# err
# err
# err
# err
# err
# err
# cost time 2.037527999999952
# terminated node: 0
# reached depth: 3
# reused simulation times: 141
# children node number: 50
# cost time 2.177882000000068
# terminated node: 0
# reached depth: 3
# reused simulation times: 204
# children node number: 50
# cost time 2.089533000000074
# terminated node: 0
# reached depth: 3
# reused simulation times: 213
# children node number: 33
# cost time 2.1892660000000888
# terminated node: 0
# reached depth: 3
# reused simulation times: 295
# children node number: 50
# cost time 3.084475999999995
# terminated node: 0
# reached depth: 3
# reused simulation times: 295
# children node number: 50
# cost time 2.692715000000021
# terminated node: 0
# reached depth: 3
# reused simulation times: 300
# children node number: 50
# cost time 2.623079000000075
# terminated node: 0
# reached depth: 3
# reused simulation times: 198
# children node number: 50
# cost time 2.5933209999999463
# terminated node: 0
# reached depth: 3
# reused simulation times: 297
# children node number: 45
# cost time 2.793805999999904
# terminated node: 0
# reached depth: 3
# reused simulation times: 300
# children node number: 50
# cost time 2.8526239999999916
# terminated node: 0
# reached depth: 3
# reused simulation times: 292
# children node number: 50
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# cost time 3.6817660000000387
# terminated node: 0
# reached depth: 3
# reused simulation times: 266
# children node number: 50
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# cost time 4.291686000000027
# terminated node: 0
# reached depth: 3
# reused simulation times: 225
# children node number: 50
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# cost time 3.445041999999944
# terminated node: 0
# reached depth: 3
# reused simulation times: 80
# children node number: 41
# err
# err
# err
# cost time 2.5880619999999226
# terminated node: 0
# reached depth: 3
# reused simulation times: 178
# children node number: 50
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# cost time 3.8031149999999343
# terminated node: 0
# reached depth: 3
# reused simulation times: 255
# children node number: 50
# err
# err
# err
# err
# err
# err
# err
# err
# cost time 3.1040919999999232
# terminated node: 0
# reached depth: 3
# reused simulation times: 239
# children node number: 50
# cost time 2.950597000000016
# terminated node: 0
# reached depth: 3
# reused simulation times: 174
# children node number: 50
# err
# err
# cost time 2.5668470000000525
# terminated node: 0
# reached depth: 3
# reused simulation times: 272
# children node number: 50
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# cost time 2.964044000000058
# terminated node: 0
# reached depth: 3
# reused simulation times: 180
# children node number: 44
# cost time 2.193840000000023
# terminated node: 0
# reached depth: 3
# reused simulation times: 264
# children node number: 39
# cost time 2.3510409999998956
# terminated node: 0
# reached depth: 3
# reused simulation times: 261
# children node number: 49
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# cost time 3.5183090000000448
# terminated node: 0
# reached depth: 3
# reused simulation times: 293
# children node number: 50
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# cost time 3.0497320000000627
# terminated node: 0
# reached depth: 3
# reused simulation times: 138
# children node number: 50
# cost time 2.3191790000000765
# terminated node: 0
# reached depth: 3
# reused simulation times: 155
# children node number: 24
# cost time 1.8638499999999567
# terminated node: 0
# reached depth: 3
# reused simulation times: 253
# children node number: 25
# cost time 2.2594990000000053
# terminated node: 0
# reached depth: 3
# reused simulation times: 268
# children node number: 21
# cost time 2.228101000000038
# terminated node: 0
# reached depth: 3
# reused simulation times: 300
# children node number: 31
# cost time 1.7212200000000166
# terminated node: 0
# reached depth: 3
# reused simulation times: 247
# children node number: 29
# cost time 1.5605310000000827
# terminated node: 79
# reached depth: 2
# reused simulation times: 230
# children node number: 1
# cost time 0.7883150000000114
# terminated node: 100
# reached depth: 1
# reused simulation times: 279
# children node number: 1
# cost time 0.6887289999999666
# terminated node: 100
# reached depth: 0
# mcts done
# pct done
# //////////////////////////////////////////////////
# Case 7
# //////////////////////////////////////////////////
# err
# err
# err
# err
# err
# err
# cost time 1.9727149999999938
# terminated node: 0
# reached depth: 3
# reused simulation times: 99
# children node number: 33
# cost time 2.0688250000000608
# terminated node: 0
# reached depth: 3
# reused simulation times: 198
# children node number: 50
# cost time 2.2400700000000597
# terminated node: 0
# reached depth: 3
# reused simulation times: 222
# children node number: 50
# cost time 2.1551279999999906
# terminated node: 0
# reached depth: 3
# reused simulation times: 300
# children node number: 50
# cost time 2.1777399999999716
# terminated node: 0
# reached depth: 3
# reused simulation times: 300
# children node number: 50
# cost time 2.1892579999999953
# terminated node: 0
# reached depth: 3
# reused simulation times: 298
# children node number: 50
# cost time 2.3817599999999857
# terminated node: 0
# reached depth: 3
# reused simulation times: 292
# children node number: 50
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# cost time 3.3098249999999325
# terminated node: 0
# reached depth: 3
# reused simulation times: 299
# children node number: 50
# cost time 2.4742929999999888
# terminated node: 0
# reached depth: 3
# reused simulation times: 292
# children node number: 50
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# cost time 2.8245299999999816
# terminated node: 44
# reached depth: 2
# reused simulation times: 214
# children node number: 50
# cost time 1.6089789999999766
# terminated node: 68
# reached depth: 1
# reused simulation times: 212
# children node number: 1
# cost time 0.5562449999999899
# terminated node: 100
# reached depth: 0
# mcts done
# pct done
# //////////////////////////////////////////////////
# Case 8
# //////////////////////////////////////////////////
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# cost time 1.8005110000000286
# terminated node: 0
# reached depth: 3
# reused simulation times: 99
# children node number: 50
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# cost time 2.034770000000094
# terminated node: 0
# reached depth: 3
# reused simulation times: 176
# children node number: 43
# cost time 2.7837979999999334
# terminated node: 0
# reached depth: 3
# reused simulation times: 199
# children node number: 43
# cost time 2.4566310000000158
# terminated node: 0
# reached depth: 3
# reused simulation times: 280
# children node number: 50
# cost time 2.9517039999999497
# terminated node: 0
# reached depth: 3
# reused simulation times: 202
# children node number: 50
# cost time 2.2746579999999312
# terminated node: 0
# reached depth: 3
# reused simulation times: 297
# children node number: 50
# err
# err
# err
# cost time 2.408798999999931
# terminated node: 0
# reached depth: 3
# reused simulation times: 224
# children node number: 50
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# cost time 2.7086480000000392
# terminated node: 0
# reached depth: 3
# reused simulation times: 292
# children node number: 50
# cost time 2.329556999999909
# terminated node: 0
# reached depth: 3
# reused simulation times: 274
# children node number: 50
# cost time 2.140535
# terminated node: 0
# reached depth: 3
# reused simulation times: 259
# children node number: 41
# cost time 2.5052309999999807
# terminated node: 0
# reached depth: 3
# reused simulation times: 300
# children node number: 50
# cost time 2.207257000000027
# terminated node: 0
# reached depth: 3
# reused simulation times: 300
# children node number: 30
# cost time 2.4959390000000212
# terminated node: 0
# reached depth: 3
# reused simulation times: 270
# children node number: 50
# cost time 2.150839000000019
# terminated node: 0
# reached depth: 3
# reused simulation times: 300
# children node number: 39
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# cost time 2.4866799999999785
# terminated node: 0
# reached depth: 3
# reused simulation times: 271
# children node number: 23
# err
# err
# cost time 1.8936780000000226
# terminated node: 0
# reached depth: 3
# reused simulation times: 292
# children node number: 50
# cost time 1.8457859999999755
# terminated node: 0
# reached depth: 3
# reused simulation times: 202
# children node number: 8
# cost time 1.372700000000009
# terminated node: 0
# reached depth: 3
# reused simulation times: 293
# children node number: 23
# cost time 1.568520000000035
# terminated node: 0
# reached depth: 3
# reused simulation times: 278
# children node number: 5
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# cost time 2.088836000000015
# terminated node: 0
# reached depth: 3
# reused simulation times: 300
# children node number: 32
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# cost time 2.170097999999939
# terminated node: 73
# reached depth: 2
# reused simulation times: 259
# children node number: 36
# cost time 1.0601159999999936
# terminated node: 100
# reached depth: 1
# reused simulation times: 136
# children node number: 1
# cost time 0.6291839999998956
# terminated node: 100
# reached depth: 0
# mcts done
# pct done
# //////////////////////////////////////////////////
# Case 9
# //////////////////////////////////////////////////
# err
# err
# err
# err
# err
# err
# err
# cost time 1.8275999999999613
# terminated node: 0
# reached depth: 3
# reused simulation times: 99
# children node number: 33
# cost time 2.0351739999999836
# terminated node: 0
# reached depth: 3
# reused simulation times: 198
# children node number: 50
# cost time 2.0971940000000586
# terminated node: 0
# reached depth: 3
# reused simulation times: 296
# children node number: 46
# cost time 2.2154600000000073
# terminated node: 0
# reached depth: 3
# reused simulation times: 296
# children node number: 45
# cost time 2.311283000000003
# terminated node: 0
# reached depth: 3
# reused simulation times: 300
# children node number: 50
# err
# err
# err
# err
# cost time 2.652612999999974
# terminated node: 0
# reached depth: 3
# reused simulation times: 300
# children node number: 50
# cost time 2.2172789999999623
# terminated node: 0
# reached depth: 3
# reused simulation times: 175
# children node number: 50
# cost time 2.535439999999994
# terminated node: 0
# reached depth: 3
# reused simulation times: 273
# children node number: 50
# cost time 2.4399799999999914
# terminated node: 0
# reached depth: 3
# reused simulation times: 300
# children node number: 50
# cost time 2.491760999999997
# terminated node: 0
# reached depth: 3
# reused simulation times: 294
# children node number: 50
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# cost time 4.064143000000058
# terminated node: 0
# reached depth: 3
# reused simulation times: 294
# children node number: 50
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# cost time 3.3690740000000687
# terminated node: 0
# reached depth: 3
# reused simulation times: 229
# children node number: 50
# err
# err
# cost time 3.046498999999926
# terminated node: 0
# reached depth: 3
# reused simulation times: 182
# children node number: 50
# err
# err
# cost time 2.8675759999999855
# terminated node: 0
# reached depth: 3
# reused simulation times: 274
# children node number: 50
# cost time 2.524285999999961
# terminated node: 0
# reached depth: 3
# reused simulation times: 276
# children node number: 50
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# cost time 3.2269309999999223
# terminated node: 0
# reached depth: 3
# reused simulation times: 272
# children node number: 50
# cost time 2.6353829999999334
# terminated node: 0
# reached depth: 3
# reused simulation times: 291
# children node number: 48
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# cost time 2.9957540000000336
# terminated node: 0
# reached depth: 3
# reused simulation times: 175
# children node number: 40
# err
# err
# err
# err
# err
# err
# err
# err
# err
# cost time 2.9011270000000877
# terminated node: 0
# reached depth: 3
# reused simulation times: 272
# children node number: 34
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# cost time 3.0344900000000052
# terminated node: 0
# reached depth: 3
# reused simulation times: 168
# children node number: 50
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# cost time 2.6886049999999386
# terminated node: 0
# reached depth: 3
# reused simulation times: 160
# children node number: 50
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# cost time 3.0923629999999775
# terminated node: 0
# reached depth: 3
# reused simulation times: 171
# children node number: 50
# cost time 2.0536329999999907
# terminated node: 0
# reached depth: 3
# reused simulation times: 256
# children node number: 43
# cost time 2.381554000000051
# terminated node: 0
# reached depth: 3
# reused simulation times: 226
# children node number: 8
# cost time 2.2909510000000637
# terminated node: 0
# reached depth: 3
# reused simulation times: 300
# children node number: 50
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# cost time 3.3245489999999336
# terminated node: 0
# reached depth: 3
# reused simulation times: 274
# children node number: 34
# cost time 2.202530999999908
# terminated node: 0
# reached depth: 3
# reused simulation times: 256
# children node number: 50
# cost time 2.191426999999976
# terminated node: 0
# reached depth: 3
# reused simulation times: 202
# children node number: 3
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# cost time 2.6639809999999216
# terminated node: 0
# reached depth: 3
# reused simulation times: 300
# children node number: 50
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# cost time 2.8982639999999265
# terminated node: 0
# reached depth: 3
# reused simulation times: 266
# children node number: 50
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# cost time 1.7422160000000986
# terminated node: 1
# reached depth: 3
# reused simulation times: 87
# children node number: 1
# cost time 0.8742619999998169
# terminated node: 100
# reached depth: 2
# reused simulation times: 186
# children node number: 1
# cost time 0.7761430000000473
# terminated node: 100
# reached depth: 1
# reused simulation times: 285
# children node number: 1
# cost time 0.6921210000000428
# terminated node: 100
# reached depth: 0
# mcts done
# pct done
# //////////////////////////////////////////////////
# Case 10
# //////////////////////////////////////////////////
# err
# err
# err
# err
# err
# err
# err
# cost time 1.5080460000001494
# terminated node: 0
# reached depth: 3
# reused simulation times: 99
# children node number: 33
# err
# err
# cost time 1.6236139999998613
# terminated node: 0
# reached depth: 3
# reused simulation times: 198
# children node number: 14
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# cost time 2.6751950000000306
# terminated node: 0
# reached depth: 3
# reused simulation times: 294
# children node number: 50
# cost time 2.257573000000093
# terminated node: 0
# reached depth: 3
# reused simulation times: 264
# children node number: 21
# err
# cost time 2.549801000000116
# terminated node: 0
# reached depth: 3
# reused simulation times: 247
# children node number: 50
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# cost time 3.4035019999998894
# terminated node: 0
# reached depth: 3
# reused simulation times: 289
# children node number: 50
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# cost time 3.904549999999972
# terminated node: 0
# reached depth: 3
# reused simulation times: 118
# children node number: 50
# err
# err
# err
# err
# err
# cost time 2.912471000000096
# terminated node: 0
# reached depth: 3
# reused simulation times: 216
# children node number: 50
# cost time 2.366078000000016
# terminated node: 0
# reached depth: 3
# reused simulation times: 167
# children node number: 50
# err
# err
# err
# err
# err
# err
# err
# err
# err
# cost time 2.5134190000001126
# terminated node: 0
# reached depth: 3
# reused simulation times: 235
# children node number: 50
# cost time 2.384962000000087
# terminated node: 0
# reached depth: 3
# reused simulation times: 278
# children node number: 50
# cost time 2.136265999999978
# terminated node: 0
# reached depth: 3
# reused simulation times: 274
# children node number: 27
# cost time 2.1005109999998695
# terminated node: 0
# reached depth: 3
# reused simulation times: 285
# children node number: 50
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# cost time 3.839145000000144
# terminated node: 0
# reached depth: 3
# reused simulation times: 240
# children node number: 50
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# cost time 2.4926339999999527
# terminated node: 0
# reached depth: 3
# reused simulation times: 237
# children node number: 40
# cost time 2.1678640000000087
# terminated node: 0
# reached depth: 3
# reused simulation times: 198
# children node number: 45
# cost time 1.8777259999999387
# terminated node: 0
# reached depth: 3
# reused simulation times: 228
# children node number: 50
# cost time 1.9468990000000304
# terminated node: 0
# reached depth: 3
# reused simulation times: 300
# children node number: 29
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# cost time 2.9460739999999532
# terminated node: 0
# reached depth: 3
# reused simulation times: 290
# children node number: 37
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# cost time 2.172882999999956
# terminated node: 0
# reached depth: 3
# reused simulation times: 220
# children node number: 20
# cost time 1.6391410000001088
# terminated node: 0
# reached depth: 3
# reused simulation times: 206
# children node number: 1
# cost time 1.7056589999999687
# terminated node: 0
# reached depth: 3
# reused simulation times: 278
# children node number: 32
# err
# err
# err
# err
# err
# err
# err
# err
# err
# cost time 1.8911820000000716
# terminated node: 0
# reached depth: 3
# reused simulation times: 299
# children node number: 50
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# cost time 1.5881999999999152
# terminated node: 1
# reached depth: 3
# reused simulation times: 276
# children node number: 9
# cost time 1.0693479999999909
# terminated node: 0
# reached depth: 3
# reused simulation times: 192
# children node number: 1
# cost time 1.1198119999999108
# terminated node: 0
# reached depth: 3
# reused simulation times: 287
# children node number: 6
# cost time 1.0237789999998768
# terminated node: 97
# reached depth: 2
# reused simulation times: 292
# children node number: 9
# cost time 0.820611000000099
# terminated node: 100
# reached depth: 1
# reused simulation times: 202
# children node number: 1
# cost time 0.6607829999998103
# terminated node: 100
# reached depth: 0
# mcts done
# pct done
# //////////////////////////////////////////////////
# Case 11
# //////////////////////////////////////////////////
# err
# err
# err
# err
# err
# err
# cost time 1.8716170000000147
# terminated node: 0
# reached depth: 3
# reused simulation times: 99
# children node number: 33
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# cost time 2.254275000000007
# terminated node: 0
# reached depth: 3
# reused simulation times: 197
# children node number: 50
# err
# err
# err
# cost time 2.2664669999999205
# terminated node: 0
# reached depth: 3
# reused simulation times: 273
# children node number: 50
# cost time 2.322774999999865
# terminated node: 0
# reached depth: 3
# reused simulation times: 273
# children node number: 50
# cost time 2.4380129999999554
# terminated node: 0
# reached depth: 3
# reused simulation times: 299
# children node number: 50
# cost time 2.4263330000001133
# terminated node: 0
# reached depth: 3
# reused simulation times: 286
# children node number: 50
# cost time 2.496556999999939
# terminated node: 0
# reached depth: 3
# reused simulation times: 300
# children node number: 50
# cost time 2.589228999999932
# terminated node: 0
# reached depth: 3
# reused simulation times: 300
# children node number: 50
# cost time 3.0632009999999354
# terminated node: 0
# reached depth: 3
# reused simulation times: 300
# children node number: 50
# err
# err
# err
# cost time 3.023792000000185
# terminated node: 0
# reached depth: 3
# reused simulation times: 300
# children node number: 50
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# cost time 3.00654899999995
# terminated node: 0
# reached depth: 3
# reused simulation times: 157
# children node number: 50
# cost time 2.9175219999999626
# terminated node: 0
# reached depth: 3
# reused simulation times: 198
# children node number: 50
# cost time 2.5275380000000496
# terminated node: 0
# reached depth: 3
# reused simulation times: 195
# children node number: 50
# cost time 2.263486000000057
# terminated node: 0
# reached depth: 3
# reused simulation times: 207
# children node number: 50
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# cost time 2.8165039999998953
# terminated node: 0
# reached depth: 3
# reused simulation times: 214
# children node number: 50
# err
# cost time 2.702046999999993
# terminated node: 0
# reached depth: 3
# reused simulation times: 284
# children node number: 50
# err
# cost time 2.743881999999985
# terminated node: 0
# reached depth: 3
# reused simulation times: 266
# children node number: 50
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# cost time 3.3556049999999686
# terminated node: 0
# reached depth: 3
# reused simulation times: 294
# children node number: 50
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# cost time 3.3535190000000057
# terminated node: 0
# reached depth: 3
# reused simulation times: 249
# children node number: 50
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# cost time 2.54333500000007
# terminated node: 0
# reached depth: 3
# reused simulation times: 119
# children node number: 45
# cost time 1.7367400000000544
# terminated node: 0
# reached depth: 3
# reused simulation times: 217
# children node number: 9
# cost time 1.7861940000000232
# terminated node: 0
# reached depth: 3
# reused simulation times: 281
# children node number: 22
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# cost time 3.1893640000000687
# terminated node: 0
# reached depth: 3
# reused simulation times: 290
# children node number: 46
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# cost time 3.1858380000001034
# terminated node: 0
# reached depth: 3
# reused simulation times: 211
# children node number: 46
# cost time 2.0054939999999988
# terminated node: 0
# reached depth: 3
# reused simulation times: 112
# children node number: 20
# cost time 2.2127649999999903
# terminated node: 0
# reached depth: 3
# reused simulation times: 207
# children node number: 22
# cost time 1.7752170000001115
# terminated node: 30
# reached depth: 3
# reused simulation times: 297
# children node number: 50
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# cost time 1.8751509999999598
# terminated node: 38
# reached depth: 3
# reused simulation times: 82
# children node number: 2
# cost time 0.7556950000000597
# terminated node: 100
# reached depth: 1
# reused simulation times: 177
# children node number: 1
# cost time 0.6617180000000644
# terminated node: 100
# reached depth: 0
# mcts done
# pct done
# //////////////////////////////////////////////////
# Case 12
# //////////////////////////////////////////////////
# err
# err
# err
# err
# err
# err
# err
# err
# err
# cost time 2.0544179999999415
# terminated node: 0
# reached depth: 3
# reused simulation times: 99
# children node number: 50
# cost time 2.1559799999999996
# terminated node: 0
# reached depth: 3
# reused simulation times: 198
# children node number: 45
# cost time 2.0215789999999743
# terminated node: 0
# reached depth: 3
# reused simulation times: 281
# children node number: 50
# cost time 2.0892570000000887
# terminated node: 0
# reached depth: 3
# reused simulation times: 300
# children node number: 50
# cost time 1.9109220000000278
# terminated node: 0
# reached depth: 3
# reused simulation times: 298
# children node number: 50
# cost time 1.989402999999811
# terminated node: 0
# reached depth: 3
# reused simulation times: 300
# children node number: 50
# cost time 1.8036150000000362
# terminated node: 0
# reached depth: 3
# reused simulation times: 298
# children node number: 50
# cost time 1.9985489999999118
# terminated node: 0
# reached depth: 3
# reused simulation times: 291
# children node number: 31
# cost time 2.176827000000003
# terminated node: 0
# reached depth: 3
# reused simulation times: 300
# children node number: 50
# cost time 2.0117250000000695
# terminated node: 0
# reached depth: 3
# reused simulation times: 293
# children node number: 50
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# cost time 2.730088999999907
# terminated node: 25
# reached depth: 3
# reused simulation times: 283
# children node number: 45
# err
# cost time 2.042852000000039
# terminated node: 0
# reached depth: 3
# reused simulation times: 130
# children node number: 9
# err
# err
# err
# err
# cost time 1.7887530000000424
# terminated node: 0
# reached depth: 3
# reused simulation times: 225
# children node number: 50
# err
# err
# err
# err
# err
# err
# cost time 2.2144349999998667
# terminated node: 0
# reached depth: 3
# reused simulation times: 279
# children node number: 50
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# cost time 2.2216880000000856
# terminated node: 0
# reached depth: 3
# reused simulation times: 288
# children node number: 28
# cost time 1.911248999999998
# terminated node: 0
# reached depth: 3
# reused simulation times: 262
# children node number: 35
# cost time 1.6066399999999703
# terminated node: 0
# reached depth: 3
# reused simulation times: 259
# children node number: 10
# err
# cost time 1.7271900000000642
# terminated node: 0
# reached depth: 3
# reused simulation times: 300
# children node number: 35
# err
# err
# err
# err
# err
# err
# cost time 2.0859080000000176
# terminated node: 0
# reached depth: 3
# reused simulation times: 282
# children node number: 24
# cost time 1.879560999999967
# terminated node: 0
# reached depth: 3
# reused simulation times: 266
# children node number: 19
# cost time 1.8738110000001598
# terminated node: 0
# reached depth: 3
# reused simulation times: 266
# children node number: 50
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# cost time 2.188848999999891
# terminated node: 0
# reached depth: 3
# reused simulation times: 295
# children node number: 7
# cost time 1.5778949999998986
# terminated node: 0
# reached depth: 3
# reused simulation times: 284
# children node number: 45
# cost time 1.5001689999999144
# terminated node: 0
# reached depth: 3
# reused simulation times: 218
# children node number: 1
# cost time 0.9186349999999948
# terminated node: 100
# reached depth: 2
# reused simulation times: 300
# children node number: 10
# cost time 0.8105979999997999
# terminated node: 100
# reached depth: 1
# reused simulation times: 269
# children node number: 1
# cost time 0.6454380000000128
# terminated node: 100
# reached depth: 0
# mcts done
# pct done
# //////////////////////////////////////////////////
# Case 13
# //////////////////////////////////////////////////
# err
# err
# err
# err
# err
# err
# cost time 1.7889709999999468
# terminated node: 0
# reached depth: 3
# reused simulation times: 99
# children node number: 50
# cost time 1.6339460000001509
# terminated node: 0
# reached depth: 3
# reused simulation times: 198
# children node number: 27
# cost time 1.5404019999998582
# terminated node: 0
# reached depth: 3
# reused simulation times: 217
# children node number: 35
# cost time 1.6626059999998688
# terminated node: 0
# reached depth: 3
# reused simulation times: 300
# children node number: 10
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# cost time 3.392808000000059
# terminated node: 0
# reached depth: 3
# reused simulation times: 297
# children node number: 50
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# cost time 4.198792999999796
# terminated node: 0
# reached depth: 3
# reused simulation times: 70
# children node number: 33
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# cost time 2.2797660000001088
# terminated node: 0
# reached depth: 3
# reused simulation times: 92
# children node number: 39
# err
# cost time 2.423285999999962
# terminated node: 0
# reached depth: 3
# reused simulation times: 184
# children node number: 50
# cost time 2.1285659999998643
# terminated node: 0
# reached depth: 3
# reused simulation times: 283
# children node number: 40
# cost time 2.1321580000001177
# terminated node: 0
# reached depth: 3
# reused simulation times: 249
# children node number: 29
# cost time 2.0071349999998347
# terminated node: 0
# reached depth: 3
# reused simulation times: 300
# children node number: 50
# err
# err
# cost time 1.7915540000001329
# terminated node: 0
# reached depth: 3
# reused simulation times: 300
# children node number: 28
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# cost time 2.2013160000001335
# terminated node: 0
# reached depth: 3
# reused simulation times: 276
# children node number: 18
# err
# err
# cost time 1.5778709999999592
# terminated node: 0
# reached depth: 3
# reused simulation times: 216
# children node number: 10
# err
# err
# err
# err
# err
# err
# err
# err
# cost time 1.9570780000001378
# terminated node: 41
# reached depth: 3
# reused simulation times: 208
# children node number: 50
# cost time 1.607138999999961
# terminated node: 68
# reached depth: 1
# reused simulation times: 208
# children node number: 1
# cost time 0.5811539999999695
# terminated node: 100
# reached depth: 0
# mcts done
# pct done
# //////////////////////////////////////////////////
# Case 14
# //////////////////////////////////////////////////
# err
# err
# err
# err
# err
# err
# err
# err
# err
# cost time 1.8268819999998414
# terminated node: 0
# reached depth: 3
# reused simulation times: 99
# children node number: 33
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# cost time 2.0599580000000515
# terminated node: 0
# reached depth: 3
# reused simulation times: 164
# children node number: 50
# cost time 1.9731140000001233
# terminated node: 0
# reached depth: 3
# reused simulation times: 261
# children node number: 50
# cost time 1.9461719999999332
# terminated node: 0
# reached depth: 3
# reused simulation times: 263
# children node number: 50
# cost time 3.144363999999996
# terminated node: 0
# reached depth: 3
# reused simulation times: 299
# children node number: 50
# cost time 2.8781870000000254
# terminated node: 0
# reached depth: 3
# reused simulation times: 300
# children node number: 50
# cost time 2.7188760000001366
# terminated node: 0
# reached depth: 3
# reused simulation times: 251
# children node number: 50
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# cost time 3.113250999999991
# terminated node: 0
# reached depth: 3
# reused simulation times: 185
# children node number: 50
# cost time 2.483024000000114
# terminated node: 0
# reached depth: 3
# reused simulation times: 283
# children node number: 50
# err
# err
# cost time 2.7131919999999354
# terminated node: 0
# reached depth: 3
# reused simulation times: 262
# children node number: 50
# err
# err
# err
# err
# cost time 2.851327999999967
# terminated node: 0
# reached depth: 3
# reused simulation times: 296
# children node number: 50
# cost time 2.403298000000177
# terminated node: 0
# reached depth: 3
# reused simulation times: 271
# children node number: 50
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# cost time 4.038544000000002
# terminated node: 0
# reached depth: 3
# reused simulation times: 255
# children node number: 50
# cost time 2.6842430000001514
# terminated node: 0
# reached depth: 3
# reused simulation times: 253
# children node number: 43
# err
# err
# err
# err
# cost time 3.5579320000001644
# terminated node: 0
# reached depth: 3
# reused simulation times: 211
# children node number: 50
# cost time 2.8089919999999893
# terminated node: 0
# reached depth: 3
# reused simulation times: 294
# children node number: 50
# cost time 2.8117600000000493
# terminated node: 0
# reached depth: 3
# reused simulation times: 244
# children node number: 50
# cost time 2.0747959999998784
# terminated node: 0
# reached depth: 3
# reused simulation times: 300
# children node number: 50
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# cost time 2.863405000000057
# terminated node: 37
# reached depth: 2
# reused simulation times: 245
# children node number: 50
# cost time 1.6766739999998208
# terminated node: 79
# reached depth: 1
# reused simulation times: 211
# children node number: 1
# cost time 0.6212310000000798
# terminated node: 100
# reached depth: 0
# mcts done
# pct done
# //////////////////////////////////////////////////
# Case 15
# //////////////////////////////////////////////////
# err
# err
# err
# err
# err
# err
# err
# err
# err
# cost time 1.5260310000001027
# terminated node: 0
# reached depth: 3
# reused simulation times: 99
# children node number: 33
# cost time 1.714554999999791
# terminated node: 0
# reached depth: 3
# reused simulation times: 198
# children node number: 50
# err
# err
# cost time 1.7240030000000388
# terminated node: 0
# reached depth: 3
# reused simulation times: 295
# children node number: 50
# cost time 1.7263469999998051
# terminated node: 0
# reached depth: 3
# reused simulation times: 200
# children node number: 50
# cost time 1.8362949999998364
# terminated node: 0
# reached depth: 3
# reused simulation times: 274
# children node number: 50
# cost time 2.032858000000033
# terminated node: 0
# reached depth: 3
# reused simulation times: 277
# children node number: 50
# cost time 2.3058039999998527
# terminated node: 0
# reached depth: 3
# reused simulation times: 300
# children node number: 50
# cost time 2.374520999999959
# terminated node: 0
# reached depth: 3
# reused simulation times: 300
# children node number: 50
# cost time 2.5214719999999033
# terminated node: 0
# reached depth: 3
# reused simulation times: 300
# children node number: 50
# cost time 2.403864999999996
# terminated node: 0
# reached depth: 3
# reused simulation times: 300
# children node number: 50
# cost time 2.6813710000001265
# terminated node: 0
# reached depth: 3
# reused simulation times: 275
# children node number: 50
# cost time 2.4585590000001503
# terminated node: 0
# reached depth: 3
# reused simulation times: 296
# children node number: 50
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# err
# cost time 3.2774500000000444
# terminated node: 0
# reached depth: 3
# reused simulation times: 269
# children node number: 50
# cost time 2.4015790000000834
# terminated node: 0
# reached depth: 3
# reused simulation times: 275
# children node number: 50
# cost time 2.2616709999999784
# terminated node: 0
# reached depth: 3
# reused simulation times: 243
# children node number: 50
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_12688/765783317.py in <module>
#       4 # args_list.append([400, None, -1])
#       5 # args_list.append([100, None, -1])
# ----> 6 result = compare_test(env, args_list, 50)
#
# /tmp/ipykernel_12688/4158602622.py in compare_test(env, args_list, times)
#      89         print('//////////////////////////////////////////////////')
#      90         start = time.time()
# ---> 91         ratio, counter, reward = testMCTS(next_box_size_list[:4], env, obser, *args_list)
#      92         end = time.time()
#      93         result['MCTS'].append([ratio, counter, reward, end-start])
#
# /tmp/ipykernel_12688/4158602622.py in testMCTS(box_size_list, env, obser, simulation_times, search_depth, rollout_length)
#      14         # print(sim_env.space.plain)
#      15         # MCTS simulation
# ---> 16         pl = mctree.get_policy(simulation_times, zeta=1e-5)
#      17         action = mctree.sample_action(pl)
#      18
#
# ~/workspace/Online-3D-BPP-PCT/MCTS/monteCarlo.py in get_policy(self, sim_times, zeta)
#      98         start = time.clock()
#      99         for i in range(sim_times):
# --> 100             self.select()
#     101         end = time.clock()
#     102         p = self.play(zeta)
#
# ~/workspace/Online-3D-BPP-PCT/MCTS/monteCarlo.py in select(self)
#      63             # Simulate time: take the action
#      64             action_idx = cur_action
# ---> 65             obs, reward, done, _ = sim2_env.step(action_idx)
#      66             next_node.reward = reward
#      67             if done:
#
# ~/workspace/Online-3D-BPP-PCT/pct_envs/PctDiscrete0/bin3D.py in step(self, action)
#     193         info = dict()
#     194         info['counter'] = len(self.space.boxes)
# --> 195         return self.cur_observation(), reward, done, info
#     196
#
# ~/workspace/Online-3D-BPP-PCT/pct_envs/PctDiscrete0/bin3D.py in cur_observation(self)
#      85
#      86         boxes.append(self.space.box_vec)
# ---> 87         leaf_nodes.append(self.get_possible_position())
#      88
#      89         next_box = sorted(list(self.next_box))
#
# KeyboardInterrupt:

# %%
for (key, value) in result.items():
    print('//////////////////////////////////////////////////')
    print(key)
    print('ratio', value[:, 0])
    print('counter',value[:, 1])
    print('reward',value[:, 2])
    print('time',value[:, 3])
    meanv = value.mean(axis=-2)
    print('mean',meanv)
    print("avg_time_per_item", meanv[-1]/meanv[1])
    # print(value.var(axis=-2))
    print('//////////////////////////////////////////////////')
# Out:
# //////////////////////////////////////////////////
# MCTS
# ratio [0.496 0.454 0.554 0.577 0.652]
# counter [11. 21. 20. 22. 19.]
# reward [4.96 4.54 5.54 5.77 6.52]
# time [21.65354395 58.42054033 53.29573488 52.47205329 42.21361017]
# mean [ 0.5466     18.6         5.466      45.61109653]
# avg_time_per_item 2.452209490601734
# //////////////////////////////////////////////////
# //////////////////////////////////////////////////
# PCT
# ratio [0.757 0.454 0.554 0.577 0.575]
# counter [21. 21. 20. 22. 17.]
# reward [7.57 4.54 5.54 5.77 5.75]
# time [0.12673831 0.17889619 0.14138365 0.15852237 0.12033701]
# mean [ 0.5834    20.2        5.834      0.1451755]
# avg_time_per_item 0.007186906172497437
# //////////////////////////////////////////////////

# %%
labels = ['ratio', 'counter', 'reward', 'time']
means_mcts = result['MCTS'].mean(axis=-2)
means_mcts[0]=float("%.2f%%" % (100 * means_mcts[0]))
means_mcts[1]=float("%.2f" % (means_mcts[1]))
means_mcts[2]=float("%.2f" % (means_mcts[2]))
means_mcts[3]=float("%.2f" % (means_mcts[3]))
means_pct = result['PCT'].mean(axis=-2)
means_pct[0]=float("%.2f" % (100 * means_pct[0]))
means_pct[1]=float("%.2f" % (means_pct[1]))
means_pct[2]=float("%.2f" % (means_pct[2]))
means_pct[3]=float("%.2f" % (means_pct[3]))
import matplotlib.pyplot as plt
plt.rcParams['font.family'] = ['Times New Roman']
fig,ax = plt.subplots(1,1,figsize=(6,4),dpi=200)
labels = labels
x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

label_font = {
    'weight':'bold',
    'size':14,
    'family':'simsun'
}

rects1 = ax.bar(x - width/2, means_mcts, width, label='MCTS',ec='k',color='white', lw=.8, hatch='...')
rects2 = ax.bar(x + width/2 + .05, means_pct, width, label='PCT',ec='k',color='white', lw=.8, hatch='***')

ax.tick_params(which='major',direction='in',length=5,width=1.5,labelsize=11,bottom=False)
ax.tick_params(axis='x',labelsize=11,bottom=False,labelrotation=15)
ax.set_xticks(x)
ax.set_ylim(ymin = 0,ymax = 100)
ax.set_yticks(np.arange(0,100,200))

ax.set_ylabel('',fontdict=label_font)
ax.set_xticklabels(labels,fontdict=label_font)
#ax.legend(markerscale=10,fontsize=12,prop=legend_font)
ax.legend(markerscale=10,fontsize=12)

# Add some text for labels, title and custom x-axis tick labels, etc.
def autolabel(rects):
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')
autolabel(rects1)
autolabel(rects2)
fig.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_12688/2960220426.py in <module>
#       1 labels = ['ratio', 'counter', 'reward', 'time']
#       2 means_mcts = result['MCTS'].mean(axis=-2)
# ----> 3 means_mcts[0]=str("%.2f%%" % (100 * means_mcts[0]))
#       4 means_mcts[1]=float("%.2f" % (means_mcts[1]))
#       5 means_mcts[2]=float("%.2f" % (means_mcts[2]))
#
# ValueError: could not convert string to float: '54.66%'

# %%
plt.rc('font', family='serif')
plt.rc('xtick', labelsize='x-small')
plt.rc('ytick', labelsize='x-small')

fig = plt.figure(figsize=(4, 3))
ax = fig.add_subplot(1, 1, 1)

x = np.linspace(1., 8., 30)
ax.plot(x, x ** 1.5, color='k', ls='solid')
ax.plot(x, 20/x, color='0.50', ls='dashed')
ax.set_xlabel('Time (s)')
ax.set_ylabel('Temperature (K)')
# Out:
# Text(0, 0.5, 'Temperature (K)')
